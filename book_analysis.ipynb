# %%
import re
import math
import random
import morfeusz2
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
def divide_into_chapters(book_lines):
    chapter_regex = re.compile(r'^[MDCLXVI]+\.(?=\s|$)', re.I)

    chapters = []
    current_chapter = []

    for line in book_lines:
        if line.strip() == "-----":
            break

        if chapter_regex.match(line.strip()):
            if current_chapter and "".join(current_chapter).strip():
                chapters.append("".join(current_chapter).strip())
                current_chapter = []
            current_chapter.append(line)
        else:
            current_chapter.append(line)

    if current_chapter:
        chapters.append("".join(current_chapter).strip())

    return chapters


def read_book():
    book_volume_one_path = "lalka/lalka-tom-pierwszy.txt"
    with open(book_volume_one_path, "r") as f:
        book_volume_one = f.readlines()

    start_index = next((i for i, line in enumerate(book_volume_one) if "Tom I" in line or line.strip() == "Tom I"), 0)
    book_volume_one = book_volume_one[start_index + 1:]

    book_volume_one_chapters = divide_into_chapters(book_volume_one)
    print(f"Read {len(book_volume_one_chapters)} chapters from volume one.")
    for chapter in book_volume_one_chapters:
        with open(f"lalka/chapters/volume_one/chapter_{book_volume_one_chapters.index(chapter) + 1}.txt", "w") as f:
            f.write(chapter)

    book_volume_two_path = "lalka/lalka-tom-drugi.txt"
    with open(book_volume_two_path, "r") as f:
        book_volume_two = f.readlines()

    start_index = next((i for i, line in enumerate(book_volume_two) if "Tom II" in line or line.strip() == "Tom II"), 0)
    book_volume_two = book_volume_two[start_index + 1:]

    book_volume_two_chapters = divide_into_chapters(book_volume_two)
    print(f"Read {len(book_volume_two_chapters)} chapters from volume two.")
    for chapter in book_volume_two_chapters:
        with open(f"lalka/chapters/volume_two/chapter_{book_volume_two_chapters.index(chapter) + 1}.txt", "w") as f:
            f.write(chapter)

    return book_volume_one_chapters + book_volume_two_chapters

book = read_book()
# Out:
# Read 20 chapters from volume one.
# Read 18 chapters from volume two.

# %%
polish_stopwords = set()
with open("polish_stopwords.txt", "r") as f:
    for line in f:
        polish_stopwords.add(line.strip())
        

def text_to_base_words(text):
    polish_morph = morfeusz2.Morfeusz()

    all_words = [word.lower() for word in text.split() if word.isalpha() and len(word) > 3]
    analyzed_base_words = [polish_morph.analyse(word)[0][2][1].lower() for word in all_words]
    analyzed_base_words = [w.split(":")[0].strip() if ":" in w else w for w in analyzed_base_words]
    
    return [word for word in analyzed_base_words if word not in polish_stopwords and len(word) >= 3]

words_in_book = text_to_base_words(" ".join(book))
words_in_chapters = [text_to_base_words(chapter) for chapter in book]

# %%
word_freq_in_book = {}
for word in words_in_book:
    word_freq_in_book[word] = word_freq_in_book.get(word, 0) + 1
sorted_word_freq_in_book = sorted(word_freq_in_book.items(), key=lambda x: x[1], reverse=True)

print("Top 20 words in the book:")
for word, freq in sorted_word_freq_in_book[:20]:
    print(f"{word}: {freq}")

WordCloud = WordCloud(width=800, height=400, background_color='white')
WordCloud.generate_from_frequencies(word_freq_in_book)
WordCloud.to_file("lalka/wordclouds/wordcloud_book.png")

word_freq_in_chapters = [{} for _ in range(len(words_in_chapters))]
sorted_word_freq_in_chapters = [{} for _ in range(len(words_in_chapters))]
for i, chapter_words in enumerate(words_in_chapters):
    for word in chapter_words:
        word_freq_in_chapters[i][word] = word_freq_in_chapters[i].get(word, 0) + 1
    sorted_word_freq_in_chapters[i] = sorted(word_freq_in_chapters[i].items(), key=lambda x: x[1], reverse=True)

for i, chapter_freq in enumerate(sorted_word_freq_in_chapters):
    print(f"\nTop 10 words in chapter {i + 1}:")
    for word, freq in chapter_freq[:10]:
        print(f"{word}: {freq}")
# Out:
# Top 20 words in the book:
# wokulski: 1441
# panna: 1096
# mówić: 750
# mieć: 626
# móc: 518
# swój: 514
# ażeby: 512
# chcieć: 507
# rzec: 472
# izabela: 452
# chwila: 437
# człowiek: 417
# soba: 411
# odeprzeć: 386
# zrobić: 347
# myśleć: 314
# wielki: 302
# czas: 296
# ręka: 291
# zacząć: 282
#
# Top 10 words in chapter 1:
# wokulski: 11
# sklep: 10
# radca: 10
# szkoła: 6
# rok: 5
# służyć: 5
# ajent: 5
# firma: 4
# mincel: 4
# kupiec: 4
#
# Top 10 words in chapter 2:
# ignacy: 13
# sklep: 10
# szanowny: 10
# swój: 9
# rzecki: 9
# mraczewski: 7
# subiekt: 6
# czas: 6
# chwila: 6
# kalosz: 6
#
# Top 10 words in chapter 3:
# sklep: 19
# ojciec: 18
# napoleon: 14
# ciotka: 14
# raczek: 14
# stary: 13
# mincel: 13
# swój: 10
# ażeby: 10
# czas: 10
#
# Top 10 words in chapter 4:
# wokulski: 24
# ignacy: 20
# mieć: 12
# mówić: 11
# rzec: 9
# tysiąc: 8
# odeprzeć: 8
# swój: 7
# chcieć: 7
# rzecki: 7
#
# Top 10 words in chapter 5:
# panna: 41
# izabela: 21
# tomasz: 18
# swój: 18
# świat: 14
# wielki: 13
# ażeby: 12
# czas: 12
# mieć: 11
# piękny: 10
#
# Top 10 words in chapter 6:
# panna: 92
# izabela: 35
# ręka: 26
# ojciec: 24
# ażeby: 20
# florentyna: 20
# chcieć: 16
# chwila: 15
# mówić: 15
# swój: 14
#
# Top 10 words in chapter 7:
# panna: 38
# izabela: 23
# wokulski: 15
# sklep: 13
# chwila: 10
# odpowiedzieć: 8
# spojrzeć: 7
# chcieć: 7
# dama: 6
# mówić: 6
#
# Top 10 words in chapter 8:
# wokulski: 54
# mieć: 24
# sklep: 20
# człowiek: 19
# swój: 17
# rzec: 16
# móc: 15
# dopiero: 14
# panna: 14
# odeprzeć: 14
#
# Top 10 words in chapter 9:
# wokulski: 96
# panna: 46
# hrabina: 35
# rzec: 27
# mówić: 24
# chcieć: 22
# odeprzeć: 20
# izabela: 19
# chwila: 18
# móc: 18
#
# Top 10 words in chapter 10:
# mówić: 39
# ażeby: 27
# móc: 27
# mieć: 27
# sklep: 25
# chwila: 23
# chcieć: 22
# soba: 22
# czas: 21
# zrobić: 21
#
# Top 10 words in chapter 11:
# wokulski: 84
# książę: 34
# panna: 28
# mówić: 27
# człowiek: 27
# móc: 21
# rzec: 18
# chcieć: 18
# odeprzeć: 17
# zdawać: 17
#
# Top 10 words in chapter 12:
# wokulski: 56
# tysiąc: 22
# mieć: 18
# panna: 15
# klacz: 14
# rubel: 14
# chwila: 13
# odeprzeć: 13
# krzeszowski: 12
# chcieć: 12
#
# Top 10 words in chapter 13:
# wokulski: 87
# baron: 38
# mówić: 27
# chcieć: 23
# panna: 22
# odeprzeć: 19
# klacz: 19
# swój: 18
# chwila: 17
# ręka: 17
#
# Top 10 words in chapter 14:
# panna: 66
# izabela: 45
# wokulski: 45
# człowiek: 21
# baron: 21
# swój: 16
# myśleć: 15
# ojciec: 14
# móc: 14
# soba: 13
#
# Top 10 words in chapter 15:
# wokulski: 13
# panna: 9
# chcieć: 8
# móc: 8
# soba: 7
# mówić: 7
# myśleć: 6
# mieć: 6
# podobny: 5
# znajomość: 5
#
# Top 10 words in chapter 16:
# panna: 39
# wokulski: 30
# izabela: 19
# tomasz: 18
# mieć: 12
# móc: 11
# chwila: 10
# swój: 9
# wielki: 8
# mówić: 8
#
# Top 10 words in chapter 17:
# wokulski: 54
# panna: 27
# mieć: 16
# soba: 15
# mówić: 15
# odeprzeć: 15
# rubel: 14
# chwila: 13
# baron: 13
# móc: 11
#
# Top 10 words in chapter 18:
# ignacy: 82
# mówić: 46
# tysiąc: 34
# łęcki: 30
# swój: 29
# wokulski: 28
# chcieć: 28
# rzecki: 25
# chwila: 21
# soba: 20
#
# Top 10 words in chapter 19:
# panna: 109
# wokulski: 58
# izabela: 49
# tomasz: 33
# tysiąc: 31
# mówić: 31
# rzec: 28
# ojciec: 27
# ażeby: 25
# móc: 24
#
# Top 10 words in chapter 20:
# stach: 46
# mówić: 28
# mieć: 26
# wokulski: 24
# móc: 18
# swój: 18
# ażeby: 15
# człowiek: 15
# czas: 15
# soba: 13
#
# Top 10 words in chapter 21:
# mówić: 31
# rządca: 28
# człowiek: 24
# mieć: 23
# rzec: 22
# młody: 21
# drzwi: 19
# baronowy: 19
# swój: 18
# móc: 17
#
# Top 10 words in chapter 22:
# wokulski: 69
# mówić: 27
# prawo: 25
# móc: 25
# paryż: 24
# ulica: 21
# człowiek: 19
# potem: 17
# suzin: 17
# mieć: 15
#
# Top 10 words in chapter 23:
# wokulski: 71
# geist: 36
# mieć: 31
# odeprzeć: 27
# rzec: 23
# swój: 21
# chwila: 19
# spytać: 19
# metal: 19
# chcieć: 18
#
# Top 10 words in chapter 24:
# baron: 25
# wokulski: 18
# panna: 15
# zrobić: 10
# myśleć: 10
# ażeby: 9
# chcieć: 8
# prezesowy: 8
# mieć: 8
# czas: 7
#
# Top 10 words in chapter 25:
# wokulski: 54
# panna: 40
# mówić: 27
# baron: 23
# mieć: 23
# starski: 22
# chwila: 21
# ochocki: 19
# prezesowy: 19
# zawołać: 17
#
# Top 10 words in chapter 26:
# panna: 99
# wokulski: 41
# izabela: 39
# baron: 22
# rzec: 19
# wąsowska: 17
# móc: 17
# mówić: 15
# mieć: 15
# starski: 15
#
# Top 10 words in chapter 27:
# panna: 93
# wokulski: 56
# izabela: 42
# mówić: 25
# rzec: 24
# mieć: 21
# chwila: 20
# czas: 20
# starski: 18
# chcieć: 18
#
# Top 10 words in chapter 28:
# wokulski: 23
# ażeby: 21
# stawska: 19
# baronowy: 17
# móc: 16
# stach: 14
# mówić: 14
# nowy: 14
# mieć: 13
# rzec: 13
#
# Top 10 words in chapter 29:
# stawska: 48
# baronowy: 40
# mówić: 31
# ażeby: 29
# sędzia: 28
# swój: 27
# lalka: 26
# wokulski: 26
# mieć: 25
# chcieć: 25
#
# Top 10 words in chapter 30:
# mówić: 45
# wokulski: 31
# mieć: 30
# stach: 22
# ażeby: 21
# stawska: 19
# panna: 19
# sklep: 18
# soba: 16
# człowiek: 15
#
# Top 10 words in chapter 31:
# panna: 53
# wokulski: 49
# izabela: 29
# mówić: 21
# mieć: 18
# stawska: 18
# wielki: 15
# móc: 15
# chcieć: 13
# swój: 13
#
# Top 10 words in chapter 32:
# panna: 74
# wokulski: 56
# izabela: 29
# rzec: 27
# mówić: 25
# ażeby: 19
# chwila: 18
# rzecki: 17
# mieć: 17
# zrobić: 16
#
# Top 10 words in chapter 33:
# baron: 26
# baronowy: 21
# mówić: 12
# rzec: 12
# odeprzeć: 12
# swój: 11
# wokulski: 11
# rubel: 10
# jaśnie: 10
# móc: 10
#
# Top 10 words in chapter 34:
# panna: 41
# wokulski: 39
# chwila: 19
# starski: 19
# izabela: 17
# zdawać: 16
# mówić: 15
# móc: 15
# chcieć: 15
# soba: 14
#
# Top 10 words in chapter 35:
# mieć: 15
# baron: 15
# ażeby: 14
# mówić: 13
# klejn: 11
# swój: 11
# szlangbaum: 10
# zrobić: 8
# swoić: 8
# chcieć: 8
#
# Top 10 words in chapter 36:
# wokulski: 127
# mieć: 61
# mówić: 59
# swój: 52
# móc: 51
# ażeby: 50
# chcieć: 47
# rzec: 46
# zrobić: 42
# soba: 39
#
# Top 10 words in chapter 37:
# móc: 5
# stach: 5
# książę: 4
# ludwik: 4
# rubel: 4
# żyd: 4
# zginąć: 3
# rzecz: 3
# świat: 3
# człowiek: 3
#
# Top 10 words in chapter 38:
# wokulski: 44
# rzecki: 38
# ażeby: 30
# mówić: 30
# mieć: 29
# ignacy: 29
# człowiek: 25
# ochocki: 24
# soba: 22
# swój: 20

# %%
def calculate_tf_idf_weights(word_freq_in_chapters):
    chapters_number = len(word_freq_in_chapters)

    weights = {}
    for chapter_index, chapter_words in enumerate(word_freq_in_chapters):
        weights[chapter_index] = {}
        for word_in_chapter, count_in_chapter in chapter_words.items():
            chapters_with_word = sum([1 if word_in_chapter in chapter else 0 for chapter in word_freq_in_chapters])
            weights[chapter_index][word_in_chapter] = count_in_chapter * math.log(chapters_number / (1 + chapters_with_word))

    return weights

tf_idf_weights = calculate_tf_idf_weights(word_freq_in_chapters)

tf_idf_weights
# Out:
# {0: {'wyglądać': 0.1112256351102244,
#   'firma': 6.76670404268429,
#   'mincel': 6.2325784721862,
#   'wokulski': 0.293350717903774,
#   'szkło': 1.8458266904983307,
#   'początki': 1.55814461804655,
#   'rok': 0.27033610635137895,
#   'świat': 0.05406722127027579,
#   'polityczny': 1.072636802264849,
#   'zajmować': 0.3794896217049037,
#   'pokój': 0.1410785982599056,
#   'wybór': 1.55814461804655,
#   'nowy': 0.1112256351102244,
#   'papież': 2.9444389791664403,
#   'szansa': 2.028148247292285,
#   'europejski': 1.8458266904983307,
#   'warszawski': 1.6916760106710724,
#   'kupiec': 1.2215265982047276,
#   'tudzież': 1.8590719172483514,
#   'inteligencja': 2.9444389791664403,
#   'pewny': 1.3862943611198906,
#   'okolica': 1.072636802264849,
#   'krakowski': 1.55814461804655,
#   'przedmieście': 1.8458266904983307,
#   'niemniej': 1.6916760106710724,
#   'gorąco': 0.8649974374866045,
#   'interesować': 0.9295359586241757,
#   'przyszłość': 1.4403615823901663,
#   'galanteryjny': 3.2179104067945468,
#   'sklep': 1.112256351102244,
#   'renomowany': 2.538973871058276,
#   'wieczorny': 2.2512917986064953,
#   'przekąska': 2.9444389791664403,
#   'zbierać': 0.9295359586241757,
#   'właściciel': 0.9295359586241757,
#   'skład': 2.8807231647803326,
#   'bielizna': 1.55814461804655,
#   'fabrykant': 3.383352021342145,
#   'powóz': 0.3794896217049037,
#   'poważny': 1.072636802264849,
#   'ojcowie': 2.538973871058276,
#   'utrzymywać': 0.9295359586241757,
#   'własny': 0.1410785982599056,
#   'posiadacz': 2.538973871058276,
#   'kamienica': 0.6931471805599453,
#   'równia': 1.1526795099383853,
#   'mówić': -0.051950972806521355,
#   'uzbrojenie': 2.9444389791664403,
#   'zatopić': 1.6916760106710724,
#   'kłąb': 2.028148247292285,
#   'dym': 1.8458266904983307,
#   'cygaro': 6.0844447418768555,
#   'pochylić': 0.8043728156701697,
#   'butelka': 2.8807231647803326,
#   'ciemny': 0.8043728156701697,
#   'szkła': 2.2512917986064953,
#   'obywatel': 1.8458266904983307,
#   'jednia': 2.7886078758725272,
#   'zakładać': 1.2396908869280152,
#   'wygranę': 2.2512917986064953,
#   'przegranę': 2.9444389791664403,
#   'drugi': 0.0,
#   'bankructwo': 4.502583597212991,
#   'nazywać': 0.9455551122569213,
#   'geniusz': 2.2512917986064953,
#   'awanturnik': 2.538973871058276,
#   'krytykować': 2.538973871058276,
#   'postępowanie': 1.55814461804655,
#   'prezydent': 2.2512917986064953,
#   'zdecydować': 0.9985288301111273,
#   'majątek': 0.3417492937220567,
#   'stanowisko': 3.1162892360931,
#   'zawdzięczać': 2.2512917986064953,
#   'wytrwały': 2.538973871058276,
#   'praca': 0.5020919437972361,
#   'radca': 16.916760106710726,
#   'dwadzieścia': 0.8374206697163701,
#   'towarzystwo': 0.3417492937220567,
#   'znać': 0.4449025404408976,
#   'dawno': 0.3794896217049037,
#   'głośnie': 2.2512917986064953,
#   'przepowiadać': 2.2512917986064953,
#   'ruina': 1.2396908869280152,
#   'niewypłacalność': 2.9444389791664403,
#   'deklewski': 5.077947742116552,
#   'muszy': 0.026668247082161273,
#   'skończyć': 0.1112256351102244,
#   'pilnować': 1.1526795099383853,
#   'fach': 2.538973871058276,
#   'uszanować': 1.6916760106710724,
#   'dar': 2.2512917986064953,
#   'łaskawy': 1.2396908869280152,
#   'głęboki': 0.6418538861723947,
#   'sentencja': 2.9444389791664403,
#   'swój': 0.0,
#   'przynieść': 0.6931471805599453,
#   'służyć': 2.297661646892201,
#   'odpowiadać': 0.3794896217049037,
#   'czas': 0.0,
#   'mruczeć': 2.145273604529698,
#   'osoba': 0.2702903297399117,
#   'posilać': 2.9444389791664403,
#   'subiekt': 0.709166334192691,
#   'chłopiec': 0.9985288301111273,
#   'przyczyna': 2.4793817738560304,
#   'klęska': 1.8458266904983307,
#   'maić': 0.24671429471091602,
#   'paść': 0.8649974374866045,
#   'gazowy': 2.2512917986064953,
#   'płomyk': 2.028148247292285,
#   'oświetlać': 2.538973871058276,
#   'tkwić': 2.028148247292285,
#   'niespokojny': 1.6916760106710724,
#   'awanturniczy': 2.9444389791664403,
#   'zresztą': 0.08223809823697201,
#   'świeży': 1.072636802264849,
#   'postępek': 2.538973871058276,
#   'ręka': -0.025975486403260677,
#   'kawałek': 1.33500106673234,
#   'chleb': 1.4403615823901663,
#   'możność': 1.6916760106710724,
#   'uczęszczać': 2.9444389791664403,
#   'przyzwoity': 2.028148247292285,
#   'dobrowolnie': 1.55814461804655,
#   'wyrzec': 1.072636802264849,
#   'zostawić': 0.6418538861723947,
#   'opatrzność': 2.2512917986064953,
#   'gotówka': 1.4403615823901663,
#   'odziedziczyć': 1.33500106673234,
#   'żona': 0.41871033485818504,
#   'pojechać': 0.6834985874441134,
#   'turecki': 1.8458266904983307,
#   'wojna': 0.7472144018302211,
#   'robić': -0.07792645920978203,
#   'dostawa': 4.05629649458457,
#   'wojska': 2.538973871058276,
#   'gruby': 0.8649974374866045,
#   'interes': 0.2224512702204488,
#   'wtrącić': 0.3336769053306732,
#   'ajent': 9.229133452491654,
#   'bywać': 0.23638877806423034,
#   'rzadki': 1.55814461804655,
#   'zrobić': 0.0,
#   'odeprzeć': 0.05333649416432255,
#   'tymczasem': 0.08223809823697201,
#   'porządny': 1.2396908869280152,
#   'diabli': 0.8649974374866045,
#   'bogacić': 2.9444389791664403,
#   'żyd': 0.7472144018302211,
#   'mruknąć': 0.3053816495511819,
#   'podać': 0.20359895524123955,
#   'siódma': 2.028148247292285,
#   'obowiązek': 0.7472144018302211,
#   'potrzebować': 0.3794896217049037,
#   'miecić': 0.08223809823697201,
#   'wiadomości': 1.33500106673234,
#   'wszechstronny': 2.9444389791664403,
#   'przenieść': 1.1526795099383853,
#   'swoić': 0.0,
#   'szklanka': 1.55814461804655,
#   'stół': 0.6418538861723947,
#   'topić': 2.028148247292285,
#   'słodki': 1.33500106673234,
#   'wejrzenie': 1.6916760106710724,
#   'załzawiony': 2.538973871058276,
#   'spytać': 0.05406722127027579,
#   'zniżyć': 0.8043728156701697,
#   'móc': -0.051950972806521355,
#   'trocha': 0.08223809823697201,
#   'wydawać': 0.23638877806423034,
#   'człowiek': 0.0,
#   'skryć': 2.9444389791664403,
#   'skrytość': 2.9444389791664403,
#   'wielki': 0.0,
#   'dumać': 2.9444389791664403,
#   'zdradzać': 1.1526795099383853,
#   'skłonność': 1.55814461804655,
#   'tegom': 2.9444389791664403,
#   'przyjąć': 0.3794896217049037,
#   'szczególny': 0.5465437063680699,
#   'oznaka': 1.55814461804655,
#   'rumiany': 1.6916760106710724,
#   'otoczyć': 0.8649974374866045,
#   'pęk': 2.9444389791664403,
#   'siwy': 0.7472144018302211,
#   'włos': 0.6931471805599453,
#   'broda': 2.8807231647803326,
#   'chwila': 0.0,
#   'podobny': -0.025975486403260677,
#   'krwawnik': 2.9444389791664403,
#   'oprawić': 2.9444389791664403,
#   'powoli': 0.5465437063680699,
#   'ogryzać': 2.9444389791664403,
#   'zapalać': 1.1526795099383853,
#   'zaczekać': 3.383352021342145,
#   'jadać': 1.1526795099383853,
#   'otóż': 0.2702903297399117,
#   'hopfera': 5.077947742116552,
#   'mieć': -0.10390194561304271,
#   'para': 0.05406722127027579,
#   'handel': 2.0794415416798357,
#   'wówczas': 0.2702903297399117,
#   'podawać': 0.6418538861723947,
#   'zraz': 2.9444389791664403,
#   'branża': 2.538973871058276,
#   'przerzucić': 5.077947742116552,
#   'przerwać': 0.23638877806423034,
#   'szkoła': 9.3488677082793,
#   'potem': 0.16220166381082737,
#   'rozum': 0.4071979104824791,
#   'zachcieć': 4.502583597212991,
#   'począć': 0.1410785982599056,
#   'chwiać': 1.33500106673234,
#   'głowa': 0.026668247082161273,
#   'oznaczać': 1.6916760106710724,
#   'istny': 1.6916760106710724,
#   'heca': 2.538973871058276,
#   'zwyczajnie': 1.8458266904983307,
#   'stosunki': 0.5020919437972361,
#   'akademia': 2.538973871058276,
#   'sztuk': 1.33500106673234,
#   'palić': 1.1526795099383853,
#   'chcieć': -0.051950972806521355,
#   'zły': 0.5020919437972361,
#   'dzienić': 0.05333649416432255,
#   'gościa': 0.5930637220029628,
#   'bufet': 2.028148247292285,
#   'prowadzić': 0.3053816495511819,
#   'noc': 0.5930637220029628,
#   'uczyć': 0.6931471805599453,
#   'licha': 1.6916760106710724,
#   'musieć': 0.0,
#   'niechętnie': 2.2512917986064953,
#   'machać': 1.4403615823901663,
#   'posługa': 2.538973871058276,
#   'niewinny': 2.2512917986064953,
#   'słówko': 1.2396908869280152,
#   'marszczyć': 1.6916760106710724,
#   'używać': 1.33500106673234,
#   'źle': 1.2396908869280152,
#   'gniewać': 0.9295359586241757,
#   'nazwać': 0.8043728156701697,
#   'zwymyślać': 1.8458266904983307,
#   'oba': 0.3794896217049037,
#   'porwać': 1.2396908869280152,
#   'cierpieć': 1.072636802264849,
#   'wcale': 0.2702903297399117,
#   'warszawa': 0.8374206697163701,
#   'rozejść': 0.9985288301111273,
#   'wstąpić': 0.5465437063680699,
#   'tłum': 1.1526795099383853,
#   'zacząć': 0.10813444254055159,
#   'przychodzić': 0.20359895524123955,
#   'osobliwie': 1.6916760106710724,
#   'roić': 4.05629649458457,
#   'pójść': 0.2821571965198112,
#   'zdać': 0.9295359586241757,
#   'egzamin': 2.028148247292285,
#   'powiedzieć': 0.05406722127027579,
#   'ciągnąć': 0.08223809823697201,
#   'uderzać': 0.6931471805599453,
#   'kolano': 1.33500106673234,
#   'zamiast': 0.23638877806423034,
#   'wytrwać': 2.9444389791664403,
#   'nauka': 1.1526795099383853,
#   'niespełna': 2.2512917986064953,
#   'rzucić': 0.34370051385331846,
#   'gotować': 2.028148247292285,
#   'wraz': 1.2396908869280152,
#   'dzień': 0.17185025692665923,
#   'rezultat': 0.5020919437972361,
#   'oprzeć': 0.45953232937844013,
#   'koło': 1.2396908869280152,
#   'westchnąć': 0.5930637220029628,
#   'koniec': 0.4071979104824791,
#   'wrócić': 0.026668247082161273,
#   'niewielki': 1.55814461804655,
#   'szukać': 0.5020919437972361,
#   'daleki': 0.3794896217049037,
#   'omijać': 2.2512917986064953,
#   'nareszcie': 0.17185025692665923,
#   'protekcja': 2.2512917986064953,
#   'dzisiejszy': 1.2396908869280152,
#   'wkręcić': 2.538973871058276,
#   'akurat': 0.6931471805599453,
#   'zostać': 0.10813444254055159,
#   'ożenić': 1.0930874127361399,
#   'baba': 2.7886078758725272,
#   'gruba': 0.9295359586241757,
#   'starsza': 2.028148247292285,
#   'głupia': 0.9985288301111273,
#   'zamach': 1.4403615823901663,
#   'zdobyć': 0.6418538861723947,
#   'soba': -0.025975486403260677,
#   'spokojnie': 0.9295359586241757,
#   'pracować': 0.9190646587568803,
#   'krzyż': 1.8458266904983307,
#   'pański': 0.23638877806423034,
#   'prawić': 0.7472144018302211,
#   'patrzeć': 0.0,
#   'znaczyć': 1.0930874127361399,
#   'półtora': 1.4403615823901663,
#   'objeść': 2.9444389791664403,
#   'czteroletni': 2.9444389791664403,
#   'katorga': 2.9444389791664403,
#   'wolny': 0.5465437063680699,
#   'zasobny': 2.9444389791664403,
#   'trzydzieści': 0.5930637220029628,
#   'tysiąc': 0.05406722127027579,
#   'rubel': 0.0,
#   'pokolenie': 1.4403615823901663,
#   'poprawić': 0.8649974374866045,
#   'miejsce': 0.1410785982599056,
#   'uczciwy': 0.8043728156701697,
#   'panienka': 1.55814461804655,
#   'żyć': 0.8043728156701697,
#   'reputacja': 3.1162892360931,
#   'doskonały': 1.072636802264849,
#   'milion': 0.5930637220029628,
#   'odezwać': 0.05406722127027579,
#   'żachnąć': 2.9444389791664403,
#   'myślić': 0.2702903297399117,
#   'turcja': 2.2512917986064953,
#   'znajda': 0.5020919437972361,
#   'bogaty': 0.7472144018302211,
#   'aniżeli': 0.1112256351102244,
#   'nieboszczka': 1.55814461804655,
#   'jechać': 0.23638877806423034,
#   'powtórzyć': 0.3053816495511819,
#   'zasłaniać': 0.9985288301111273,
#   'twarz': 0.1410785982599056,
#   'mima': 0.2702903297399117,
#   'posępny': 1.55814461804655,
#   'wróżba': 2.538973871058276,
#   'trzeźwo': 2.538973871058276,
#   'dobry': 0.0,
#   'publiczność': 2.028148247292285,
#   'zaciekawić': 2.538973871058276,
#   'pogłoska': 2.2512917986064953,
#   'licznie': 2.9444389791664403,
#   'odwiedzać': 1.1526795099383853,
#   'opuścić': 0.3794896217049037,
#   'zgłaszać': 2.538973871058276,
#   'towar': 0.9295359586241757,
#   'zamówienie': 2.9444389791664403,
#   'mnożyć': 1.55814461804655,
#   'kredyt': 1.6916760106710724,
#   'granica': 0.9985288301111273,
#   'weksel': 1.33500106673234,
#   'płacić': 0.45953232937844013,
#   'ledwo': 2.028148247292285,
#   'mogel': 1.33500106673234,
#   'wydołać': 2.9444389791664403,
#   'trzy': 0.16447619647394401,
#   'mizerny': 0.9985288301111273,
#   'godzina': 0.08223809823697201,
#   'umierać': 2.2512917986064953,
#   'szatyn': 2.9444389791664403,
#   'ruch': 0.5020919437972361,
#   'książę': 0.6931471805599453,
#   'trzeci': 0.17185025692665923,
#   'nosić': 0.6418538861723947,
#   'zabójczy': 2.9444389791664403,
#   'płeć': 1.8458266904983307,
#   'piękny': 0.1410785982599056,
#   'pachnąć': 2.028148247292285,
#   'laboratorium': 1.6916760106710724,
#   'ciekawość': 1.55814461804655,
#   'fizyczny': 2.028148247292285,
#   'duchowy': 2.028148247292285,
#   'zaleta': 1.55814461804655,
#   'ustalić': 1.8458266904983307,
#   'uchronić': 2.028148247292285,
#   'zawiadować': 2.9444389791664403,
#   'czterdziestoletni': 2.538973871058276,
#   'pracownik': 2.9444389791664403,
#   'przyjaciel': 0.2702903297399117,
#   'zastępca': 2.538973871058276,
#   'ignacy': 0.7472144018302211},
#  1: {'rząd': 3.719072660784046,
#   'stare': 0.3794896217049037,
#   'subiekt': 1.418332668385382,
#   'ignacy': 9.713787223792874,
#   'dwadzieścia': 0.41871033485818504,
#   'pięć': 0.3417492937220567,
#   'mieszkać': 0.8374206697163701,
#   'pokoik': 1.8458266904983307,
#   'ciąg': 0.3417492937220567,
#   'czas': 0.0,
#   'sklep': 1.112256351102244,
#   'zmieniać': 0.9295359586241757,
#   'właściciel': 0.9295359586241757,
#   'szafa': 6.198454434640076,
#   'szyb': 1.8458266904983307,
#   'zakres': 2.9444389791664403,
#   'swój': 0.0,
#   'działalność': 2.538973871058276,
#   'pokój': 0.2821571965198112,
#   'rzecki': 3.7683930137236654,
#   'pozostać': 1.2396908869280152,
#   'smutny': 1.925561658517184,
#   'wychodzący': 2.2512917986064953,
#   'szczebel': 2.9444389791664403,
#   'zwieszać': 2.2512917986064953,
#   'ćwierćwiekowy': 5.8888779583328805,
#   'pewność': 0.5465437063680699,
#   'niegdyś': 2.4793817738560304,
#   'obecnie': 1.072636802264849,
#   'wypłowieć': 2.9444389791664403,
#   'tęsknota': 3.383352021342145,
#   'okno': 0.6874010277066369,
#   'stać': 0.24671429471091602,
#   'czarny': 1.7791911660088884,
#   'stół': 0.6418538861723947,
#   'obić': 5.0750280320132175,
#   'wielki': 0.0,
#   'kałamarz': 2.2512917986064953,
#   'wraz': 1.2396908869280152,
#   'czarna': 1.55814461804655,
#   'przymocować': 2.9444389791664403,
#   'podstawka': 2.538973871058276,
#   'para': 0.21626888508110317,
#   'mosiężny': 3.6916533809966614,
#   'lichtarz': 2.538973871058276,
#   'świeca': 2.028148247292285,
#   'nikt': 0.32895239294788803,
#   'stalowy': 1.55814461804655,
#   'obcinać': 2.538973871058276,
#   'żelazny': 2.145273604529698,
#   'łóżko': 3.459989749946418,
#   'cienki': 1.4403615823901663,
#   'używać': 1.33500106673234,
#   'pudło': 2.028148247292285,
#   'przypominać': 1.256131004574555,
#   'dziecinny': 1.6916760106710724,
#   'wąski': 1.6916760106710724,
#   'kanapka': 5.077947742116552,
#   'krzesło': 1.256131004574555,
#   'skóra': 1.6916760106710724,
#   'dużać': 2.028148247292285,
#   'blaszany': 1.8458266904983307,
#   'miednica': 2.538973871058276,
#   'mała': 0.8649974374866045,
#   'ciemnowiśniowy': 2.9444389791664403,
#   'barwy': 1.8458266904983307,
#   'stanowić': 0.5020919437972361,
#   'umeblować': 2.538973871058276,
#   'wzgląd': 0.7472144018302211,
#   'swoić': 0.0,
#   'długość': 2.028148247292285,
#   'mrok': 1.8458266904983307,
#   'zdawać': 0.0,
#   'podobny': -0.10390194561304271,
#   'grób': 1.1526795099383853,
#   'aniżeli': 0.2224512702204488,
#   'równia': 2.3053590198767706,
#   'zmienić': 0.5930637220029628,
#   'ćwierć': 2.9444389791664403,
#   'wiek': 1.0041838875944722,
#   'zwyczaj': 0.9985288301111273,
#   'rano': 0.9985288301111273,
#   'budzić': 1.0930874127361399,
#   'chwila': 0.0,
#   'leżący': 1.6916760106710724,
#   'spoglądać': 0.41871033485818504,
#   'tworzyć': 0.8649974374866045,
#   'linia': 4.502583597212991,
#   'chcieć': -0.07792645920978203,
#   'wstać': 0.5465437063680699,
#   'chłodny': 1.8458266904983307,
#   'noga': 0.8374206697163701,
#   'nieco': 0.45953232937844013,
#   'zesztywniały': 2.9444389791664403,
#   'ręka': -0.07792645920978203,
#   'okazywać': 1.6916760106710724,
#   'uległy': 2.9444389791664403,
#   'zrywać': 1.2396908869280152,
#   'nagle': 0.08223809823697201,
#   'wyskakiwać': 2.2512917986064953,
#   'środek': 0.5465437063680699,
#   'rzucić': 0.5155507707799777,
#   'biec': 1.3862943611198906,
#   'piec': 1.4403615823901663,
#   'stopa': 1.2396908869280152,
#   'rżeć': 2.538973871058276,
#   'parskać': 2.028148247292285,
#   'wiekowy': 2.538973871058276,
#   'rumak': 2.538973871058276,
#   'szlachetny': 0.5930637220029628,
#   'przypomnieć': 0.2702903297399117,
#   'obrządek': 2.538973871058276,
#   'wycierać': 2.028148247292285,
#   'kosmaty': 2.9444389791664403,
#   'upodobać': 2.028148247292285,
#   'patrzyć': 0.1112256351102244,
#   'chudy': 1.6916760106710724,
#   'łydka': 2.9444389791664403,
#   'zarośnięty': 2.028148247292285,
#   'przeć': 0.1410785982599056,
#   'nabierać': 1.8458266904983307,
#   'zeskakiwać': 2.028148247292285,
#   'stary': 0.4449025404408976,
#   'pudel': 2.538973871058276,
#   'wybita': 2.9444389791664403,
#   'oko': 0.2821571965198112,
#   'mocno': 0.41871033485818504,
#   'otrząsnąć': 1.8458266904983307,
#   'resztka': 1.4403615823901663,
#   'skrobać': 5.077947742116552,
#   'rozlegać': 0.9985288301111273,
#   'pracowity': 2.538973871058276,
#   'dmuchać': 2.9444389791664403,
#   'wciąż': 0.17185025692665923,
#   'ubierać': 1.2396908869280152,
#   'wypuszczać': 2.9444389791664403,
#   'mówić': -0.07792645920978203,
#   'dzienić': 0.13334123541080636,
#   'dobry': 0.0,
#   'wydobywać': 3.718143834496703,
#   'mylić': 2.145273604529698,
#   'zapinać': 2.2512917986064953,
#   'podwórze': 1.55814461804655,
#   'zobaczyć': 0.08223809823697201,
#   'stan': 0.3417492937220567,
#   'parzyć': 2.9444389791664403,
#   'gorący': 1.1526795099383853,
#   'czesać': 2.2512917986064953,
#   'patrzeć': 0.0,
#   'lustro': 1.8458266904983307,
#   'wpół': 3.719072660784046,
#   'siódmy': 1.33500106673234,
#   'obejrzeć': 0.8043728156701697,
#   'krawat': 1.55814461804655,
#   'zegarek': 4.67443385413965,
#   'portmonetka': 1.8458266904983307,
#   'stolik': 0.8649974374866045,
#   'klucz': 1.2396908869280152,
#   'trocha': 0.16447619647394401,
#   'uroczyście': 1.072636802264849,
#   'otwierać': 0.9190646587568803,
#   'tylny': 2.4793817738560304,
#   'drzwi': 0.4727775561284607,
#   'wchodzić': 0.8649974374866045,
#   'oba': 0.7589792434098074,
#   'zapalać': 2.3053590198767706,
#   'płomyk': 2.028148247292285,
#   'gazu': 2.9444389791664403,
#   'służący': 1.6396311191042097,
#   'zamiatać': 2.538973871058276,
#   'odczytywać': 2.538973871058276,
#   'binokle': 3.1162892360931,
#   'notatnik': 2.2512917986064953,
#   'rozkład': 2.538973871058276,
#   'zajęcia': 2.67000213346468,
#   'bank': 1.6916760106710724,
#   'osiemset': 1.55814461804655,
#   'lublin': 2.538973871058276,
#   'wysłać': 1.2396908869280152,
#   'trzy': 0.08223809823697201,
#   'tuzin': 2.538973871058276,
#   'wiedeń': 2.028148247292285,
#   'przekaz': 2.9444389791664403,
#   'tysiąc': 0.10813444254055159,
#   'dwieście': 0.8043728156701697,
#   'kolej': 0.9295359586241757,
#   'odebrać': 0.8649974374866045,
#   'zmonitować': 2.9444389791664403,
#   'rymarz': 2.9444389791664403,
#   'odesłać': 1.4403615823901663,
#   'napisać': 0.5020919437972361,
#   'list': 0.2702903297399117,
#   'skończyć': 0.2224512702204488,
#   'płomień': 2.538973871058276,
#   'blask': 1.072636802264849,
#   'robić': -0.051950972806521355,
#   'przegląd': 2.2512917986064953,
#   'towar': 0.9295359586241757,
#   'gablotka': 5.077947742116552,
#   'szafirowy': 1.6916760106710724,
#   'wczoraj': 0.8374206697163701,
#   'wazon': 1.8458266904983307,
#   'lalka': 3.1162892360931,
#   'jutro': 0.8374206697163701,
#   'postawić': 0.8649974374866045,
#   'fontanna': 2.538973871058276,
#   'ósma': 2.9955864903333818,
#   'założyć': 1.6087456313403394,
#   'klejn': 2.9955864903333818,
#   'mraczewski': 7.508457615853942,
#   'poznać': 0.2702903297399117,
#   'guwernantka': 2.9444389791664403,
#   'kupić': 0.1410785982599056,
#   'neseserka': 2.538973871058276,
#   'rachunek': 1.1526795099383853,
#   'rozum': 0.20359895524123955,
#   'byle': 0.3794896217049037,
#   'zacząć': 0.21626888508110317,
#   'kupować': 0.6418538861723947,
#   'rabat': 2.538973871058276,
#   'mruczeć': 1.072636802264849,
#   'chodzić': 0.34370051385331846,
#   'zatrzymywać': 0.8649974374866045,
#   'oglądać': 0.5930637220029628,
#   'pies': 1.072636802264849,
#   'przysiadać': 2.538973871058276,
#   'podłoga': 1.2396908869280152,
#   'gęsty': 1.6916760106710724,
#   'ustawić': 1.1526795099383853,
#   'średni': 1.4403615823901663,
#   'brunetka': 2.9444389791664403,
#   'przypatrywać': 0.6107632991023638,
#   'martwy': 2.8807231647803326,
#   'sień': 0.9295359586241757,
#   'skrzypnąć': 2.2512917986064953,
#   'ukazać': 0.3053816495511819,
#   'mizerny': 1.9970576602222545,
#   'uśmiech': 0.9190646587568803,
#   'posiniały': 2.2512917986064953,
#   'przyjść': 0.05333649416432255,
#   'rzec': 0.08000474124648382,
#   'światło': 3.1162892360931,
#   'wbiec': 2.9955864903333818,
#   'ciężki': 0.5930637220029628,
#   'kłus': 2.2512917986064953,
#   'zakręcić': 2.2512917986064953,
#   'rozlec': 1.2396908869280152,
#   'zgrzytać': 2.9444389791664403,
#   'szczękać': 2.2512917986064953,
#   'sztab': 2.2512917986064953,
#   'wejść': 0.32895239294788803,
#   'jedyny': 0.7472144018302211,
#   'zawodzić': 2.2512917986064953,
#   'usiąść': 0.3053816495511819,
#   'kantorek': 1.8458266904983307,
#   'stanąć': 0.8374206697163701,
#   'zwykły': 0.8043728156701697,
#   'miejsce': 0.5643143930396224,
#   'pryncypał': 1.55814461804655,
#   'mieć': -0.07792645920978203,
#   'spytać': 0.10813444254055159,
#   'spodziewać': 0.5020919437972361,
#   'połowa': 0.3417492937220567,
#   'zatrzymać': 0.3794896217049037,
#   'nowa': 0.6834985874441134,
#   'wokulski': 0.08000474124648382,
#   'poprawić': 0.8649974374866045,
#   'pisać': 0.45953232937844013,
#   'wojna': 2.2416432054906634,
#   'kursa': 2.538973871058276,
#   'flota': 2.9444389791664403,
#   'angielski': 1.2396908869280152,
#   'wpłynąć': 1.6916760106710724,
#   'zresztą': 0.08223809823697201,
#   'westchnąć': 0.5930637220029628,
#   'obchodzić': 0.6418538861723947,
#   'przyjąć': 0.7589792434098074,
#   'udział': 1.6916760106710724,
#   'bonaparte': 2.538973871058276,
#   'uśmiechnąć': 0.3794896217049037,
#   'ironicznie': 1.8458266904983307,
#   'czyjże': 2.9444389791664403,
#   'korzyść': 2.2512917986064953,
#   'macmahon': 2.2512917986064953,
#   'ducrotem': 2.9444389791664403,
#   'układać': 2.4793817738560304,
#   'styczeń': 1.4403615823901663,
#   'zamach': 2.8807231647803326,
#   'wierzyć': 0.3794896217049037,
#   'bonapartyzm': 2.9444389791664403,
#   'oburzyć': 1.3862943611198906,
#   'republika': 2.538973871058276,
#   'szepnąć': 0.20359895524123955,
#   'kryć': 1.55814461804655,
#   'mocnieć': 1.3862943611198906,
#   'zasadzić': 2.028148247292285,
#   'podnieść': 0.17185025692665923,
#   'pragnąć': 0.9295359586241757,
#   'obalić': 2.028148247292285,
#   'przeciwstawiać': 2.9444389791664403,
#   'poplątać': 2.9444389791664403,
#   'szyk': 2.538973871058276,
#   'drugie': 1.1861274440059255,
#   'uszanować': 1.6916760106710724,
#   'zwrócić': 0.6834985874441134,
#   'zimny': 1.1526795099383853,
#   'godzina': 0.16447619647394401,
#   'muszy': 0.05333649416432255,
#   'chyba': 0.08223809823697201,
#   'kwadrans': 0.8043728156701697,
#   'pański': 0.709166334192691,
#   'spieszyć': 2.2512917986064953,
#   'późnić': 2.538973871058276,
#   'wieczor': 0.3417492937220567,
#   'odeprzeć': 0.08000474124648382,
#   'cierpko': 2.9444389791664403,
#   'lisiecki': 4.992644150555636,
#   'ocierać': 1.55814461804655,
#   'szron': 2.9444389791664403,
#   'pokryć': 1.6916760106710724,
#   'doba': 1.6916760106710724,
#   'wystarczyć': 0.9985288301111273,
#   'widok': 0.3794896217049037,
#   'galanteria': 3.6916533809966614,
#   'wola': 0.5930637220029628,
#   'szpakowaty': 1.55814461804655,
#   'łysy': 2.9444389791664403,
#   'syknąć': 1.8458266904983307,
#   'dziedzictwo': 2.9444389791664403,
#   'siwizna': 5.8888779583328805,
#   'gderliwy': 2.9444389791664403,
#   'charakter': 2.2512917986064953,
#   'owoc': 1.8458266904983307,
#   'pierwszy': 0.10813444254055159,
#   'kobieta': 0.17185025692665923,
#   'ubrany': 1.33500106673234,
#   'salopa': 2.538973871058276,
#   'chustka': 0.8043728156701697,
#   'żądać': 1.7791911660088884,
#   'nisko': 1.33500106673234,
#   'ukłonić': 0.6418538861723947,
#   'ofiarować': 0.7472144018302211,
#   'zniknąć': 0.5930637220029628,
#   'wrócić': 0.026668247082161273,
#   'doręczyć': 2.028148247292285,
#   'interesantka': 2.9444389791664403,
#   'ruch': 1.0041838875944722,
#   'pełny': 0.23638877806423034,
#   'godność': 1.8458266904983307,
#   'potem': 0.16220166381082737,
#   'zapisać': 1.2396908869280152,
#   'cena': 1.072636802264849,
#   'spluwaczka': 2.9444389791664403,
#   'podać': 0.4071979104824791,
#   'ramię': 0.45953232937844013,
#   'pójść': 0.4232357947797168,
#   'minąć': 0.5465437063680699,
#   'złożyć': 0.08223809823697201,
#   'dobroczynny': 2.9444389791664403,
#   'spór': 4.502583597212991,
#   'łysina': 2.538973871058276,
#   'dopiero': 0.05333649416432255,
#   'dziewiąty': 1.072636802264849,
#   'raczy': 0.5020919437972361,
#   'wpaść': 0.41871033485818504,
#   'dwudziestokilkoletni': 2.9444389791664403,
#   'usta': 0.7472144018302211,
#   'wąsik': 1.6916760106710724,
#   'zatruć': 1.55814461804655,
#   'ciągnąć': 0.16447619647394401,
#   'siebie': 0.10813444254055159,
#   'próg': 0.8649974374866045,
#   'smuga': 2.2512917986064953,
#   'wonia': 2.9444389791664403,
#   'słowo': 0.709166334192691,
#   'honor': 1.6087456313403394,
#   'letkiewicz': 2.538973871058276,
#   'gałgan': 2.028148247292285,
#   'podły': 0.7472144018302211,
#   'matka': 0.8043728156701697,
#   'zachorować': 2.538973871058276,
#   'musieć': 0.0,
#   'szukać': 0.5020919437972361,
#   'dawać': 0.1410785982599056,
#   'doktór': 1.2396908869280152,
#   'zacny': 0.8649974374866045,
#   'dochodzić': 2.2512917986064953,
#   'szczególny': 0.5465437063680699,
#   'nacisk': 2.2512917986064953,
#   'projektować': 2.028148247292285,
#   'wcześnie': 1.2396908869280152,
#   'ażeby': 0.0,
#   'wyjść': 0.026668247082161273,
#   'wtrącić': 0.1112256351102244,
#   'utkwić': 2.028148247292285,
#   'błękitny': 1.6916760106710724,
#   'malować': 1.2396908869280152,
#   'wysoki': 0.3794896217049037,
#   'człowiek': 0.0,
#   'zmysł': 2.9444389791664403,
#   'miasto': 0.5465437063680699,
#   'choćby': 0.1410785982599056,
#   'wybuchnąć': 0.9295359586241757,
#   'wolny': 0.5465437063680699,
#   'dziwić': 0.3417492937220567,
#   'wstąpić': 0.5465437063680699,
#   'tamten': 0.41871033485818504,
#   'latać': 1.33500106673234,
#   'spódniczka': 2.9444389791664403,
#   'odezwać': 0.05406722127027579,
#   'bawić': 0.3794896217049037,
#   'krzyknąć': 0.8649974374866045,
#   'uderzać': 0.6931471805599453,
#   'pięść': 0.9985288301111273,
#   'przynajmniej': 0.1410785982599056,
#   'wygadać': 2.2512917986064953,
#   'życie': 0.16447619647394401,
#   'niedołęga': 2.538973871058276,
#   'mruknąć': 0.6107632991023638,
#   'uśmiechać': 0.9190646587568803,
#   'podnosić': 0.5020919437972361,
#   'jednocześnie': 1.0041838875944722,
#   'brew': 1.1526795099383853,
#   'drugi': 0.0,
#   'gość': 3.2179104067945468,
#   'zażądać': 1.55814461804655,
#   'naprzeciw': 0.6418538861723947,
#   'wysunąć': 0.9985288301111273,
#   'kaloszyk': 2.9444389791664403,
#   'szanowny': 7.472144018302211,
#   'wolno': 0.5930637220029628,
#   'myśleć': 0.0,
#   'numer': 1.4403615823901663,
#   'należeć': 0.4232357947797168,
#   'raczyć': 0.6418538861723947,
#   'zająć': 0.5930637220029628,
#   'przynieść': 1.3862943611198906,
#   'zdejm': 2.9444389791664403,
#   'kalosz': 15.233843226349656,
#   'wytrzeć': 2.3053590198767706,
#   'paweł': 2.2512917986064953,
#   'ścierka': 2.9444389791664403,
#   'tłomaczyć': 0.7472144018302211,
#   'odurzyć': 1.6916760106710724,
#   'prosić': 0.05406722127027579,
#   'prędko': 0.45953232937844013,
#   'podawać': 0.6418538861723947,
#   'sczepić': 2.9444389791664403,
#   'nitka': 2.538973871058276,
#   'pysznie': 2.2512917986064953,
#   'normalna': 2.9444389791664403,
#   'niepodobny': 1.55814461804655,
#   'życzyć': 1.6087456313403394,
#   'soba': -0.10390194561304271,
#   'maić': 0.16447619647394401,
#   'ton': 0.5020919437972361,
#   'bystry': 1.6916760106710724,
#   'potok': 1.33500106673234,
#   'wymowa': 2.2512917986064953,
#   'grzeczny': 1.6916760106710724,
#   'przybić': 2.9444389791664403,
#   'łaska': 0.9295359586241757,
#   'kazać': 0.1410785982599056,
#   'zawinąć': 1.4403615823901663,
#   'dawny': 0.2702903297399117,
#   'okręcić': 2.538973871058276,
#   'dźwigać': 2.3053590198767706,
#   'zbyteczny': 2.538973871058276,
#   'rubel': 0.0,
#   'kopiejka': 6.0844447418768555,
#   'literka': 2.9444389791664403,
#   'przykry': 0.8043728156701697,
#   'znaleźć': 0.1410785982599056,
#   'nowy': 0.1112256351102244,
#   'artykuł': 1.8458266904983307,
#   'dziurawy': 2.2512917986064953,
#   'pięćdziesiąt': 1.6087456313403394,
#   'reszta': 1.0041838875944722,
#   'ubrać': 0.8043728156701697,
#   'wydać': 0.17185025692665923,
#   'niski': 0.7472144018302211,
#   'ukłon': 1.55814461804655,
#   'odprowadzić': 1.1526795099383853,
#   'interesant': 1.8458266904983307,
#   'bezmyślnie': 2.538973871058276,
#   'spoza': 0.6418538861723947,
#   'darzyć': 2.538973871058276,
#   'słodki': 1.33500106673234,
#   'ognisty': 2.028148247292285,
#   'wreszcie': 0.41871033485818504,
#   'machnąć': 1.2396908869280152,
#   'literek': 2.9444389791664403,
#   'kosztować': 0.8649974374866045,
#   'dziesięć': 0.17185025692665923,
#   'kiwać': 1.2396908869280152,
#   'głowa': 0.026668247082161273,
#   'oznaczać': 1.6916760106710724,
#   'podziwić': 2.2512917986064953,
#   'dostrzec': 0.8649974374866045,
#   'kąt': 0.9985288301111273,
#   'podbiec': 2.2512917986064953,
#   'profil': 2.9444389791664403,
#   'napoleon': 0.8649974374866045,
#   'chorować': 1.6916760106710724,
#   'kamień': 0.9985288301111273,
#   'dowcip': 2.2512917986064953,
#   'skrzywić': 2.028148247292285,
#   'droga': 0.3053816495511819,
#   'dostać': 0.08223809823697201,
#   'urlop': 2.2512917986064953,
#   'siódma': 2.028148247292285,
#   'późno': 0.1410785982599056,
#   'prywatny': 2.028148247292285,
#   'katalog': 5.077947742116552,
#   'otrzymać': 0.5930637220029628,
#   'hugonot': 2.9444389791664403,
#   'ósmy': 1.8458266904983307,
#   'niejaki': 0.8043728156701697,
#   'pociecha': 2.028148247292285,
#   'móc': -0.051950972806521355,
#   'posiadać': 0.5020919437972361,
#   'notatka': 2.2512917986064953,
#   'znać': 0.1112256351102244,
#   'szczegół': 1.33500106673234,
#   'południ': 0.9985288301111273,
#   'zdać': 0.9295359586241757,
#   'kasa': 1.33500106673234,
#   'ciągły': 1.072636802264849,
#   'ufać': 1.55814461804655,
#   'wymykać': 1.8458266904983307,
#   'zjeść': 1.2396908869280152,
#   'obiad': 0.8043728156701697,
#   'współcześnie': 1.8458266904983307,
#   'wychodzić': 1.0930874127361399,
#   'wracać': 0.41871033485818504,
#   'zostawać': 3.383352021342145,
#   'szla': 1.33500106673234,
#   'trzeci': 0.17185025692665923,
#   'wieczór': 1.072636802264849,
#   'zamykać': 1.2396908869280152,
#   'rozchodzić': 2.028148247292285,
#   'dzienny': 2.2512917986064953,
#   'sprawdzać': 2.028148247292285,
#   'plan': 2.8807231647803326,
#   'czynność': 2.028148247292285,
#   'zrobić': 0.0,
#   'wypadać': 0.9985288301111273,
#   'zaniedbać': 2.2512917986064953,
#   'sprawa': 0.3053816495511819,
#   'opłacać': 2.538973871058276,
#   'długi': 0.5020919437972361,
#   'bezsenność': 2.9444389791664403,
#   'smętny': 2.9444389791664403,
#   'marzenia': 1.6916760106710724,
#   'temat': 2.538973871058276,
#   'ruina': 1.2396908869280152,
#   'stanowczy': 1.55814461804655,
#   'upadek': 2.028148247292285,
#   'napoleonida': 2.2512917986064953,
#   'wszystek': 0.4232357947797168,
#   'ginąć': 1.55814461804655,
#   'wzdychać': 0.9985288301111273,
#   'przewracać': 1.8458266904983307,
#   'twardy': 1.4403615823901663,
#   'udać': 0.7472144018302211,
#   'wówczas': 0.810870989219735,
#   'sen': 3.1162892360931,
#   'czytać': 0.41871033485818504,
#   'historia': 0.6931471805599453,
#   'konsulat': 2.538973871058276,
#   'cesarstwo': 2.538973871058276,
#   'wycinka': 2.9444389791664403,
#   'gazeta': 1.4403615823901663,
#   'opisywać': 2.2512917986064953,
#   'włoski': 2.028148247292285,
#   'rok': 0.05406722127027579,
#   'trafiać': 1.1526795099383853,
#   'spod': 0.7472144018302211,
#   'gitara': 2.538973871058276,
#   'grać': 0.6418538861723947,
#   'marsz': 2.538973871058276,
#   'rakoczy': 2.9444389791664403,
#   'przyśpiewywać': 2.9444389791664403,
#   'wątpliwy': 2.028148247292285,
#   'wartość': 0.9985288301111273,
#   'śnić': 1.2396908869280152,
#   'obszerny': 1.55814461804655,
#   'węgierski': 1.55814461804655,
#   'granatowy': 1.55814461804655,
#   'biały': 0.45953232937844013,
#   'przysłonić': 2.028148247292285,
#   'chmura': 1.6916760106710724,
#   'nazajutrz': 1.8458266904983307,
#   'miewać': 1.072636802264849,
#   'posępny': 1.55814461804655,
#   'humor': 1.1526795099383853,
#   'skarżyć': 1.55814461804655,
#   'przyjemny': 1.072636802264849,
#   'obmyślać': 2.9444389791664403,
#   'wykonywać': 1.1526795099383853,
#   'wystawić': 2.538973871058276,
#   'okienny': 2.538973871058276,
#   'pojąć': 1.8458266904983307,
#   'streszczać': 2.538973871058276,
#   'zasoby': 2.9444389791664403,
#   'powinny': 0.7472144018302211,
#   'zwracać': 1.1861274440059255,
#   'uwaga': 0.5020919437972361,
#   'przechodzień': 1.55814461804655,
#   'bądź': 1.256131004574555,
#   'modny': 2.028148247292285,
#   'piękny': 0.1410785982599056,
#   'prawy': 1.2396908869280152,
#   'przeznaczyć': 1.33500106673234,
#   'zbytkowny': 2.538973871058276,
#   'mieścić': 1.2396908869280152,
#   'zwykle': 1.2837077723447894,
#   'porcelanowy': 2.538973871058276,
#   'zastawa': 2.9444389791664403,
#   'buduarowy': 2.9444389791664403,
#   'dokoła': 0.9985288301111273,
#   'ustawiać': 4.05629649458457,
#   'towarzystwo': 0.3417492937220567,
#   'parasol': 2.028148247292285,
#   'niezliczony': 2.538973871058276,
#   'ilość': 1.8458266904983307,
#   'elegancki': 1.2396908869280152,
#   'lewy': 0.8649974374866045,
#   'napełnić': 0.9985288301111273,
#   'okaz': 2.2512917986064953,
#   'środkowy': 2.538973871058276,
#   'zajmować': 0.3794896217049037,
#   'poruszający': 2.9444389791664403,
#   'niekiedy': 0.6834985874441134,
#   'samotny': 1.8458266904983307,
#   'stola': 0.9985288301111273,
#   'mechaniczny': 2.2512917986064953,
#   'niedźwiedź': 2.538973871058276,
#   'wdrapywać': 1.8458266904983307,
#   'piać': 5.077947742116552,
#   'toczyć': 0.7472144018302211,
#   'cyrkowy': 2.538973871058276,
#   'cwałować': 2.538973871058276,
#   'tańczyć': 3.6916533809966614,
#   'walc': 1.8458266904983307,
#   'dźwięk': 1.4403615823901663,
#   'niewyraźny': 1.6916760106710724,
#   'figura': 1.072636802264849,
#   'nakręcać': 2.9444389791664403,
#   'puszczać': 1.33500106673234,
#   'kogut': 2.028148247292285,
#   'łopotać': 2.9444389791664403,
#   'sztywny': 2.538973871058276,
#   'potykać': 2.9444389791664403,
#   'ołowiany': 2.538973871058276,
#   'pasażer': 2.538973871058276,
#   'jechać': 0.23638877806423034,
#   'zdziwić': 0.5930637220029628,
#   'świat': 0.05406722127027579,
#   'drgać': 1.4403615823901663,
#   'nabrać': 0.9295359586241757,
#   'fantastyczny': 1.6916760106710724,
#   'podeprzeć': 2.028148247292285,
#   'łokieć': 1.4403615823901663,
#   'śmiać': 0.1112256351102244,
#   'cicho': 0.5465437063680699,
#   'narażać': 0.9295359586241757,
#   'wykręcić': 2.538973871058276,
#   'sprężyna': 1.6916760106710724,
#   'powrót': 1.2837077723447894,
#   'monolog': 2.9444389791664403,
#   'szybka': 0.41871033485818504,
#   'składać': 0.5020919437972361,
#   'zabawka': 1.8458266904983307,
#   'rozdrażnić': 1.4403615823901663,
#   'puste': 1.4403615823901663,
#   'brudny': 1.1526795099383853,
#   'głupstwo': 3.458038529815156,
#   'podróż': 2.145273604529698,
#   'początek': 0.45953232937844013,
#   'koniec': 0.20359895524123955,
#   'gdzież': 0.45953232937844013,
#   'rodzaj': 0.5465437063680699,
#   'zdanie': 0.8649974374866045,
#   'wypowiadać': 1.6916760106710724,
#   'głośno': 0.5930637220029628,
#   'uważać': 0.23638877806423034,
#   'poważny': 1.072636802264849,
#   'córka': 0.7472144018302211,
#   'nieraz': 0.45953232937844013,
#   'czego': 0.1410785982599056,
#   'prowadzić': 0.3053816495511819,
#   'mężczyzna': 0.5930637220029628,
#   'dom': 0.08223809823697201,
#   'rzadko': 1.2396908869280152,
#   'krótko': 1.072636802264849,
#   'kręcić': 0.5465437063680699,
#   'kolega': 1.1526795099383853,
#   'oficjalista': 2.538973871058276,
#   'ciemnozielony': 2.2512917986064953,
#   'algierka': 2.9444389791664403,
#   'tabaczkowy': 2.2512917986064953,
#   'popielaty': 1.4403615823901663,
#   'spodnie': 1.2396908869280152,
#   'lampas': 2.9444389791664403,
#   'wypłowiały': 2.2512917986064953,
#   'nieśmiały': 2.028148247292285,
#   'zachować': 1.2396908869280152,
#   'powszechny': 2.2512917986064953,
#   'wiedzieć': 0.1112256351102244,
#   'zniechęcać': 1.8458266904983307,
#   'woleć': 0.5930637220029628,
#   'święto': 1.8458266904983307,
#   'kłaść': 0.9985288301111273,
#   'zakratować': 3.6916533809966614,
#   'widać': 0.41871033485818504,
#   'szary': 0.8649974374866045,
#   'sąsiedni': 2.028148247292285,
#   'ozdobić': 1.33500106673234,
#   'garnczek': 2.538973871058276,
#   'masło': 2.538973871058276,
#   'wisieć': 1.4403615823901663,
#   'zwłoki': 2.2512917986064953,
#   'mniej': 0.3053816495511819,
#   'marzyć': 0.8649974374866045,
#   'daleki': 0.3794896217049037,
#   'wieś': 1.55814461804655,
#   'spotykać': 1.072636802264849,
#   'zielony': 0.7472144018302211,
#   'pole': 1.2396908869280152,
#   'ciemny': 0.8043728156701697,
#   'błąkać': 2.2512917986064953,
#   'młody': 0.23638877806423034,
#   'powoli': 0.5465437063680699,
#   'zbudzić': 1.1526795099383853,
#   'głuch': 2.028148247292285,
#   'postanowić': 0.6418538861723947,
#   'wyjechać': 0.6931471805599453,
#   'miesiąc': 0.45953232937844013,
#   'wiadomo': 0.8043728156701697,
#   'dobrowolnie': 1.55814461804655,
#   'odcięty': 2.538973871058276,
#   'natura': 0.7472144018302211,
#   'utopić': 1.33500106673234,
#   'ciasny': 1.33500106673234,
#   'wir': 2.9444389791664403,
#   'sklepowy': 1.2396908869280152,
#   'czuć': 0.23638877806423034,
#   'potrzeba': 0.5020919437972361,
#   'wymian': 2.538973871058276,
#   'rozmawiać': 0.17185025692665923,
#   'duży': 0.20359895524123955,
#   'sekret': 1.072636802264849,
#   'pisywać': 1.4403615823901663},
#  2: {'pamiętnik': 1.33500106673234,
#   'stare': 1.138468865114711,
#   'subiekt': 1.1819438903211517,
#   'smutek': 1.4403615823901663,
#   'świat': 0.10813444254055159,
#   'mniej': 0.6107632991023638,
#   'dobry': 0.0,
#   'rozumny': 1.8458266904983307,
#   'stosować': 1.55814461804655,
#   'skromny': 1.6916760106710724,
#   'kwartał': 4.502583597212991,
#   'ubierać': 1.2396908869280152,
#   'spodnie': 1.2396908869280152,
#   'nowy': 0.4449025404408976,
#   'dziwny': 0.20359895524123955,
#   'kapelusz': 0.6931471805599453,
#   'inaczej': 0.7472144018302211,
#   'wykładać': 2.028148247292285,
#   'podobnież': 2.538973871058276,
#   'dzisiejsi': 2.028148247292285,
#   'polityk': 5.077947742116552,
#   'zmieniać': 0.9295359586241757,
#   'onegdaj': 1.072636802264849,
#   'wierzyć': 1.138468865114711,
#   'wczoraj': 0.41871033485818504,
#   'niedawno': 0.8043728156701697,
#   'widać': 0.8374206697163701,
#   'sklep': 2.1132870670942636,
#   'możny': 0.2821571965198112,
#   'stroić': 1.8458266904983307,
#   'modny': 2.028148247292285,
#   'przeciwny': 1.55814461804655,
#   'gościa': 1.7791911660088884,
#   'zabraknąć': 1.55814461804655,
#   'sklepowy': 1.2396908869280152,
#   'należeć': 0.2821571965198112,
#   'opierać': 0.9985288301111273,
#   'szczęśliwy': 0.7472144018302211,
#   'wielki': 0.0,
#   'metternich': 2.9444389791664403,
#   'sławny': 3.1162892360931,
#   'palmerston': 2.9444389791664403,
#   'beaconsfielda': 2.9444389791664403,
#   'któż': 0.5465437063680699,
#   'tymczasem': 0.24671429471091602,
#   'bonapartych': 7.616921613174828,
#   'trząść': 2.67000213346468,
#   'europa': 2.538973871058276,
#   'napoleon': 12.109964124812464,
#   'potem': 0.27033610635137895,
#   'niektóry': 1.072636802264849,
#   'nazywać': 0.23638877806423034,
#   'wpływać': 2.2512917986064953,
#   'los': 1.2396908869280152,
#   'francja': 1.4403615823901663,
#   'wierny': 0.9295359586241757,
#   'swój': 0.0,
#   'macmahona': 2.9444389791664403,
#   'zrobić': 0.0,
#   'napoleonka': 1.8458266904983307,
#   'cichy': 0.7472144018302211,
#   'uczyć': 0.6931471805599453,
#   'sztuk': 2.67000213346468,
#   'wojenny': 2.9444389791664403,
#   'pisanina': 2.9444389791664403,
#   'chcieć': -0.20780389122608542,
#   'mówić': -0.15585291841956406,
#   'ażeby': 0.0,
#   'tworzyć': 0.8649974374866045,
#   'rozsądny': 1.4403615823901663,
#   'interes': 0.3336769053306732,
#   'przykład': 0.9295359586241757,
#   'dom': 0.16447619647394401,
#   'ojciec': 4.254998005156146,
#   'młodu': 1.55814461804655,
#   'starość': 1.55814461804655,
#   'woźny': 1.6916760106710724,
#   'komisja': 5.8888779583328805,
#   'sprawa': 0.9161449486535458,
#   'trzymać': 1.3669971748882268,
#   'prosto': 0.9985288301111273,
#   'mieć': -0.20780389122608542,
#   'nieduży': 1.55814461804655,
#   'faworyt': 1.8458266904983307,
#   'szyja': 0.6931471805599453,
#   'okręcać': 2.9444389791664403,
#   'czarna': 1.55814461804655,
#   'chustka': 0.8043728156701697,
#   'nosić': 0.6418538861723947,
#   'srebrny': 1.1526795099383853,
#   'kolczyk': 2.028148247292285,
#   'mieszkać': 0.41871033485818504,
#   'stary': 1.4459332564329173,
#   'miasto': 0.5465437063680699,
#   'urzędnik': 2.2512917986064953,
#   'prać': 2.028148247292285,
#   'łatać': 2.2512917986064953,
#   'czwarty': 1.3862943611198906,
#   'piętro': 0.8649974374866045,
#   'niewiele': 1.1526795099383853,
#   'przynajmniej': 0.1410785982599056,
#   'izdebka': 2.538973871058276,
#   'okazały': 2.028148247292285,
#   'sprzęt': 1.55814461804655,
#   'powrócić': 1.072636802264849,
#   'biuro': 4.502583597212991,
#   'kleić': 5.8888779583328805,
#   'ciotka': 13.01350342073846,
#   'pierwszy': 0.27033610635137895,
#   'miejsce': 0.2821571965198112,
#   'zajmować': 0.7589792434098074,
#   'pogodny': 2.2512917986064953,
#   'dna': 1.072636802264849,
#   'puszczać': 1.33500106673234,
#   'ulica': 1.7087464686102836,
#   'słota': 2.9444389791664403,
#   'wydmuchiwać': 2.538973871058276,
#   'izba': 3.6916533809966614,
#   'bańka': 2.9444389791664403,
#   'ściana': 1.4944288036604423,
#   'wisieć': 5.761446329560665,
#   'dorównać': 2.9444389791664403,
#   'liczba': 1.8458266904983307,
#   'przyozdabiać': 2.538973871058276,
#   'swoić': 0.0,
#   'drugi': 0.0,
#   'trzeci': 0.34370051385331846,
#   'piąty': 1.33500106673234,
#   'dzień': 1.2029517984866147,
#   'szósty': 2.145273604529698,
#   'zgorszyć': 2.538973871058276,
#   'tyle': 1.8590719172483514,
#   'świecki': 2.9444389791664403,
#   'zawiesić': 3.383352021342145,
#   'mosiężny': 1.8458266904983307,
#   'obrazić': 0.9985288301111273,
#   'kupić': 0.1410785982599056,
#   'soba': -0.1298774320163034,
#   'brązowy': 1.55814461804655,
#   'popiersie': 2.9444389791664403,
#   'umieścić': 0.8043728156701697,
#   'niedowiarek': 2.538973871058276,
#   'lamentować': 2.2512917986064953,
#   'nieraz': 1.3785969881353204,
#   'pławić': 2.9444389791664403,
#   'cesarz': 1.4403615823901663,
#   'krzywda': 2.2512917986064953,
#   'odpowiadać': 0.3794896217049037,
#   'przychodzić': 0.8143958209649582,
#   'dawny': 0.2702903297399117,
#   'kolega': 1.1526795099383853,
#   'dunaj': 2.538973871058276,
#   'stragan': 2.9444389791664403,
#   'prościć': 2.538973871058276,
#   'lud': 0.4727775561284607,
#   'domański': 20.31179096846621,
#   'trocha': 0.08223809823697201,
#   'lubić': 0.5405806594798234,
#   'roztropny': 2.9444389791664403,
#   'wyłączać': 1.8458266904983307,
#   'twierdzić': 2.028148247292285,
#   'umrzeć': 1.0930874127361399,
#   'znajda': 1.5062758313917084,
#   'przyjść': 0.08000474124648382,
#   'dopóki': 2.5104597189861804,
#   'uporządkować': 1.8458266904983307,
#   'gotowy': 0.9985288301111273,
#   'wiedzieć': 0.4449025404408976,
#   'godzina': 0.24671429471091602,
#   'dodawać': 1.4403615823901663,
#   'fajka': 2.028148247292285,
#   'znak': 2.67000213346468,
#   'potwierdzenie': 2.9444389791664403,
#   'pluć': 11.777755916665761,
#   'pokój': 0.1410785982599056,
#   'napluć': 2.538973871058276,
#   'acan': 2.2512917986064953,
#   'wołać': 0.9985288301111273,
#   'jejmość': 12.168889483753711,
#   'wziąć': 0.2224512702204488,
#   'mruknąć': 0.9161449486535458,
#   'raczek': 28.39407546209199,
#   'strona': 1.2215937314474372,
#   'cham': 2.9444389791664403,
#   'gniewać': 0.9295359586241757,
#   'smakować': 2.028148247292285,
#   'późno': 0.5643143930396224,
#   'ożenić': 2.1861748254722797,
#   'zupełnie': 0.2821571965198112,
#   'wybić': 6.753875395819486,
#   'pracować': 0.45953232937844013,
#   'nauczyć': 0.9985288301111273,
#   'musztrować': 5.8888779583328805,
#   'musztr': 2.9444389791664403,
#   'zapędzać': 2.9444389791664403,
#   'wczesny': 2.538973871058276,
#   'plecy': 4.502583597212991,
#   'wyglądać': 0.3336769053306732,
#   'obrót': 3.1162892360931,
#   'ramię': 0.9190646587568803,
#   'naprzód': 1.0041838875944722,
#   'ciągnąć': 0.24671429471091602,
#   'odpowiedni': 1.6916760106710724,
#   'kierunek': 0.9985288301111273,
#   'ogon': 2.2512917986064953,
#   'dokładnie': 1.55814461804655,
#   'prowadzony': 4.05629649458457,
#   'noc': 0.5930637220029628,
#   'budzić': 1.0930874127361399,
#   'wymyślać': 1.9970576602222545,
#   'kończyć': 0.7472144018302211,
#   'bądź': 0.41871033485818504,
#   'bonaparte': 5.077947742116552,
#   'porządek': 2.4793817738560304,
#   'dopóty': 4.05629649458457,
#   'wypełnić': 2.2512917986064953,
#   'testament': 1.8458266904983307,
#   'móc': -0.18182840482282475,
#   'niezachwiany': 2.538973871058276,
#   'wiara': 1.33500106673234,
#   'sprawiedliwość': 1.072636802264849,
#   'podzielać': 2.9444389791664403,
#   'dokuczyć': 2.2512917986064953,
#   'kląć': 2.2512917986064953,
#   'stękać': 2.9444389791664403,
#   'długo': 1.2396908869280152,
#   'czekać': 0.5020919437972361,
#   'siwieć': 2.538973871058276,
#   'zaczynać': 0.6107632991023638,
#   'źle': 1.2396908869280152,
#   'niedługo': 0.9295359586241757,
#   'porobić': 3.6916533809966614,
#   'dziad': 2.028148247292285,
#   'chyba': 0.32895239294788803,
#   'śpiewać': 1.2396908869280152,
#   'pójść': 0.2821571965198112,
#   'najmłodsi': 2.9444389791664403,
#   'diabeł': 1.1526795099383853,
#   'słyszeć': 0.2702903297399117,
#   'zapamiętać': 2.2512917986064953,
#   'odeprzeć': 0.08000474124648382,
#   'mrugać': 1.2396908869280152,
#   'oko': 0.4232357947797168,
#   'upadać': 2.67000213346468,
#   'zły': 0.5020919437972361,
#   'wikt': 5.8888779583328805,
#   'kwatera': 2.538973871058276,
#   'zabrać': 1.0041838875944722,
#   'tyczyć': 1.6916760106710724,
#   'dawno': 0.3794896217049037,
#   'rozweselić': 2.9444389791664403,
#   'szklanka': 3.1162892360931,
#   'napić': 2.2512917986064953,
#   'doczekać': 8.458380053355363,
#   'odpowiedzieć': 0.2821571965198112,
#   'choćby': 0.4232357947797168,
#   'spytać': 0.16220166381082737,
#   'ignaś': 2.538973871058276,
#   'wówczas': 0.5405806594798234,
#   'zdanie': 0.8649974374866045,
#   'głęboko': 0.6931471805599453,
#   'wyrzynać': 2.9444389791664403,
#   'dopiero': 0.1066729883286451,
#   'późny': 3.6916533809966614,
#   'wypadek': 1.5062758313917084,
#   'nadać': 2.028148247292285,
#   'nieomal': 4.502583597212991,
#   'proroczy': 5.077947742116552,
#   'rok': 0.32440332762165475,
#   'zacząć': 0.10813444254055159,
#   'czas': 0.0,
#   'para': 0.27033610635137895,
#   'wychodzić': 0.5465437063680699,
#   'wreszcie': 1.6748413394327402,
#   'lec': 1.8458266904983307,
#   'odwiedzać': 1.1526795099383853,
#   'patrzeć': 0.0,
#   'chudy': 1.6916760106710724,
#   'ręka': -0.15585291841956406,
#   'wyżółkły': 2.9444389791664403,
#   'policzek': 1.8458266904983307,
#   'spokojnie': 0.9295359586241757,
#   'pokiwać': 1.8458266904983307,
#   'otrzeć': 0.9985288301111273,
#   'myśleć': 0.0,
#   'śmierć': 1.6396311191042097,
#   'kołatać': 2.538973871058276,
#   'przyjąć': 0.3794896217049037,
#   'ostatni': 0.34370051385331846,
#   'wbiec': 0.9985288301111273,
#   'dziwnie': 0.8043728156701697,
#   'wzburzyć': 1.33500106673234,
#   'stać': 0.16447619647394401,
#   'środek': 1.0930874127361399,
#   'znaleźć': 0.2821571965198112,
#   'krzyknąć': 1.729994874973209,
#   'jużci': 1.55814461804655,
#   'zerwać': 0.5020919437972361,
#   'upaść': 1.6087456313403394,
#   'wyciągnąć': 0.8043728156701697,
#   'życie': 0.16447619647394401,
#   'przekonać': 0.4727775561284607,
#   'poglądy': 2.028148247292285,
#   'widzieć': 0.24671429471091602,
#   'druga': 0.4071979104824791,
#   'gwiazda': 1.2396908869280152,
#   'obudzić': 0.6418538861723947,
#   'włochy': 2.028148247292285,
#   'chociaż': 0.5465437063680699,
#   'spadły': 1.6916760106710724,
#   'ostateczny': 1.33500106673234,
#   'gambetta': 2.9444389791664403,
#   'niesprawiedliwość': 2.9444389791664403,
#   'władać': 1.6916760106710724,
#   'miesiąc': 0.9190646587568803,
#   'wraz': 1.2396908869280152,
#   'zuzanna': 2.9444389791664403,
#   'zebrać': 0.6418538861723947,
#   'powoli': 0.5465437063680699,
#   'wypromować': 2.9444389791664403,
#   'zalecać': 2.028148247292285,
#   'zapytać': 0.17185025692665923,
#   'czego': 0.4232357947797168,
#   'zauważyć': 0.8043728156701697,
#   'drzwi': 1.418332668385382,
#   'okno': 1.0311015415599554,
#   'wtrącić': 0.1112256351102244,
#   'spróbować': 1.2396908869280152,
#   'rzec': 0.05333649416432255,
#   'znać': 0.2224512702204488,
#   'zgoda': 2.538973871058276,
#   'plunąć': 1.4403615823901663,
#   'bóg': 0.5930637220029628,
#   'miłosierny': 1.8458266904983307,
#   'jęknąć': 1.55814461804655,
#   'drab': 2.538973871058276,
#   'brat': 1.8458266904983307,
#   'nieszczęśliwy': 0.5930637220029628,
#   'odezwać': 0.16220166381082737,
#   'wyjść': 0.05333649416432255,
#   'gdzież': 0.45953232937844013,
#   'smarować': 2.9444389791664403,
#   'ciężko': 0.7472144018302211,
#   'schylać': 2.2512917986064953,
#   'wypukać': 2.9444389791664403,
#   'popiół': 2.9444389791664403,
#   'rozpłakać': 1.33500106673234,
#   'robić': -0.15585291841956406,
#   'duha': 1.925561658517184,
#   'pobrać': 2.028148247292285,
#   'przygarnąć': 2.9444389791664403,
#   'mielić': 0.6931471805599453,
#   'tani': 1.6916760106710724,
#   'mincel': 20.25588003460515,
#   'oddać': 0.34370051385331846,
# ...
#   'zabawny': 1.1526795099383853,
#   'trafiać': 2.3053590198767706,
#   'lepsza': 0.8043728156701697,
#   'napoleon': 1.729994874973209,
#   'mały': 0.5155507707799777,
#   'jechać': 1.418332668385382,
#   'zadumać': 2.538973871058276,
#   'wstać': 1.0930874127361399,
#   'pójść': 0.2821571965198112,
#   'zgorszenie': 2.2512917986064953,
#   'zabronić': 1.4403615823901663,
#   'następny': 1.8590719172483514,
#   'dzienić': 0.13334123541080636,
#   'odleżeć': 2.9444389791664403,
#   'doba': 1.6916760106710724,
#   'para': 0.21626888508110317,
#   'zajść': 2.145273604529698,
#   'starozakonny': 2.028148247292285,
#   'szczerość': 2.028148247292285,
#   'koncept': 2.538973871058276,
#   'połowa': 0.6834985874441134,
#   'września': 7.616921613174828,
#   'odwiedzić': 1.8590719172483514,
#   'przyjechać': 2.0794415416798357,
#   'gorąco': 0.8649974374866045,
#   'ściskać': 0.6834985874441134,
#   'kochać': 0.810870989219735,
#   'ochocki': 20.75993849967851,
#   'ojciec': 0.9455551122569213,
#   'bodaj': 3.459989749946418,
#   'imię': 2.67000213346468,
#   'przeżegnać': 1.55814461804655,
#   'ileż': 0.9985288301111273,
#   'zgubić': 0.9295359586241757,
#   'pokiwać': 1.8458266904983307,
#   'ciekawie': 1.6916760106710724,
#   'sekret': 1.072636802264849,
#   'lato': 0.5930637220029628,
#   'oświadczyć': 0.9295359586241757,
#   'wtrącić': 0.556128175551122,
#   'przyjąć': 1.8974481085245185,
#   'stary': 1.112256351102244,
#   'zebrać': 1.2837077723447894,
#   'manatki': 2.9444389791664403,
#   'żona': 1.256131004574555,
#   'wieś': 1.55814461804655,
#   'ciotka': 0.9295359586241757,
#   'mieszkać': 1.6748413394327402,
#   'wraz': 1.2396908869280152,
#   'mądry': 2.3053590198767706,
#   'marszałek': 3.458038529815156,
#   'jeździć': 1.1861274440059255,
#   'towarzystwo': 1.02524788116617,
#   'inżynier': 2.028148247292285,
#   'ruina': 1.2396908869280152,
#   'zamek': 5.761446329560665,
#   'rozpędzać': 2.9444389791664403,
#   'kobieta': 1.8903528261932516,
#   'perswadować': 2.9444389791664403,
#   'wyrzekać': 2.028148247292285,
#   'pewnie': 0.8649974374866045,
#   'przydybać': 2.9444389791664403,
#   'przekonać': 0.23638877806423034,
#   'brać': 0.3053816495511819,
#   'siebie': 0.32440332762165475,
#   'naiwny': 1.8458266904983307,
#   'inżynierka': 2.9444389791664403,
#   'asystencja': 2.538973871058276,
#   'tęsknić': 8.01000640039404,
#   'domyślać': 1.0930874127361399,
#   'wypadać': 0.9985288301111273,
#   'osioł': 1.8458266904983307,
#   'naiwność': 2.2512917986064953,
#   'spostrzec': 1.3514516486995585,
#   'wszystek': 0.9875501878193391,
#   'dna': 1.072636802264849,
#   'zazdrosny': 2.538973871058276,
#   'zaprzestać': 2.538973871058276,
#   'konkury': 2.2512917986064953,
#   'litwa': 2.9444389791664403,
#   'hrabina': 0.6931471805599453,
#   'dostać': 0.08223809823697201,
#   'poczciwy': 1.4944288036604423,
#   'łęcki': 1.5179584868196148,
#   'kiwnąć': 1.1526795099383853,
#   'palec': 4.483286410981327,
#   'skończyć': 0.2224512702204488,
#   'opowiadać': 1.3862943611198906,
#   'objąć': 2.3053590198767706,
#   'śmiać': 0.3336769053306732,
#   'rodzaj': 0.5465437063680699,
#   'tyle': 0.9295359586241757,
#   'niegłupi': 2.538973871058276,
#   'niezły': 1.8458266904983307,
#   'grunt': 2.67000213346468,
#   'tysiące': 0.6931471805599453,
#   'westchnąć': 1.1861274440059255,
#   'klasa': 1.8458266904983307,
#   'majętny': 1.8458266904983307,
#   'niewiele': 1.1526795099383853,
#   'zużywać': 2.538973871058276,
#   'rozpusta': 2.538973871058276,
#   'nerwówa': 2.9444389791664403,
#   'potrzebny': 1.33500106673234,
#   'świetnie': 2.538973871058276,
#   'wytresować': 2.538973871058276,
#   'jedyna': 0.9295359586241757,
#   'zaciągnąć': 3.6916533809966614,
#   'właściwie': 1.072636802264849,
#   'przykro': 1.33500106673234,
#   'potknąć': 2.538973871058276,
#   'rozmowa': 2.372254888011851,
#   'urwać': 2.028148247292285,
#   'kiedyż': 1.2396908869280152,
#   'zniżyć': 1.6087456313403394,
#   'dziwić': 1.02524788116617,
#   'nagły': 2.3053590198767706,
#   'obiecać': 1.2396908869280152,
#   'załatwić': 2.4793817738560304,
#   'pewien': 0.8649974374866045,
#   'niezawodnie': 1.4403615823901663,
#   'zapomnieć': 0.7589792434098074,
#   'pański': 0.23638877806423034,
#   'spodziewać': 0.5020919437972361,
#   'podoba': 1.33500106673234,
#   'pisać': 0.9190646587568803,
#   'kręcić': 1.0930874127361399,
#   'musieć': 0.0,
#   'wybuchnąć': 0.9295359586241757,
#   'bankrut': 2.2512917986064953,
#   'ożenić': 0.5465437063680699,
#   'znaleźć': 0.1410785982599056,
#   'ożywiać': 1.8458266904983307,
#   'pochwycić': 0.6931471805599453,
#   'sprawiać': 4.05629649458457,
#   'przyjemność': 0.8649974374866045,
#   'blisko': 1.3862943611198906,
#   'pytać': 0.1410785982599056,
#   'słowo': 0.4727775561284607,
#   'szeroki': 2.8807231647803326,
#   'wybijać': 2.538973871058276,
#   'takt': 2.538973871058276,
#   'wpatrować': 1.8458266904983307,
#   'wytłomaczyć': 3.1162892360931,
#   'uśmiechnąć': 0.7589792434098074,
#   'lud': 0.709166334192691,
#   'mała': 0.8649974374866045,
#   'dbać': 1.4403615823901663,
#   'sięgać': 1.8458266904983307,
#   'myśl': 1.6916760106710724,
#   'dzisiejszy': 3.719072660784046,
#   'wstręt': 3.1162892360931,
#   'byle': 1.138468865114711,
#   'spokojnie': 1.8590719172483514,
#   'facet': 2.028148247292285,
#   'troszczyć': 2.3053590198767706,
#   'nieraz': 0.45953232937844013,
#   'kilkadziesiąt': 1.2837077723447894,
#   'nieznany': 1.55814461804655,
#   'pociągać': 2.2512917986064953,
#   'żelazo': 2.2512917986064953,
#   'namysł': 1.6916760106710724,
#   'rusza': 2.028148247292285,
#   'magnes': 2.538973871058276,
#   'pszczoła': 2.2512917986064953,
#   'lepić': 2.9444389791664403,
#   'idea': 1.6916760106710724,
#   'oba': 0.7589792434098074,
#   'drżeć': 0.5930637220029628,
#   'głupi': 2.4131184470105094,
#   'żydowski': 1.6916760106710724,
#   'cywilizacja': 1.8458266904983307,
#   'stworzyć': 0.9985288301111273,
#   'polegać': 2.67000213346468,
#   'myślenie': 2.9444389791664403,
#   'święty': 2.372254888011851,
#   'piękne': 2.0794415416798357,
#   'zaawanturować': 2.9444389791664403,
#   'wzruszać': 0.9295359586241757,
#   'dusić': 3.6916533809966614,
#   'aspiracja': 2.9444389791664403,
#   'instynkta': 2.538973871058276,
#   'marny': 1.6916760106710724,
#   'zwalić': 1.6916760106710724,
#   'pretensja': 1.072636802264849,
#   'szczęście': 0.6834985874441134,
#   'łatwie': 1.4403615823901663,
#   'pogodzić': 1.2396908869280152,
#   'otoczenie': 2.2512917986064953,
#   'zużyć': 1.8458266904983307,
#   'energia': 1.6916760106710724,
#   'nietęgo': 2.9444389791664403,
#   'wyrwać': 1.2396908869280152,
#   'znajda': 1.0041838875944722,
#   'europ': 2.028148247292285,
#   'wleźć': 1.55814461804655,
#   'robota': 1.8458266904983307,
#   'naprawdę': 1.256131004574555,
#   'wyczerpać': 2.2512917986064953,
#   'wiek': 0.5020919437972361,
#   'odejść': 0.9295359586241757,
#   'okno': 0.5155507707799777,
#   'oprzeć': 0.45953232937844013,
#   'futryna': 2.9444389791664403,
#   'podobno': 0.8374206697163701,
#   'małe': 1.4403615823901663,
#   'zdawać': 0.0,
#   'gimnazjum': 2.538973871058276,
#   'egzamin': 2.028148247292285,
#   'pięć': 1.3669971748882268,
#   'przejście': 1.6916760106710724,
#   'kursa': 2.538973871058276,
#   'łacina': 2.9444389791664403,
#   'grek': 2.9444389791664403,
#   'siedem': 0.9295359586241757,
#   'wykręcić': 2.538973871058276,
#   'książka': 0.8043728156701697,
#   'łaciński': 6.753875395819486,
#   'gmach': 1.8458266904983307,
#   'unikać': 3.383352021342145,
#   'pracować': 0.45953232937844013,
#   'opuścić': 1.8974481085245185,
#   'uczyć': 1.3862943611198906,
#   'trwała': 1.55814461804655,
#   'miesiąc': 0.9190646587568803,
#   'pierwej': 0.8649974374866045,
#   'uspokoić': 0.6418538861723947,
#   'piec': 1.4403615823901663,
#   'podręcznik': 2.9444389791664403,
#   'grecki': 6.753875395819486,
#   'spalić': 1.55814461804655,
#   'paskudzić': 2.9444389791664403,
#   'ostatecznie': 1.072636802264849,
#   'popioły': 2.538973871058276,
#   'wysypać': 2.538973871058276,
#   'dostawać': 1.2396908869280152,
#   'bicie': 1.8458266904983307,
#   'litera': 4.502583597212991,
#   'kończyć': 1.4944288036604423,
#   'umykać': 2.538973871058276,
#   'stąd': 1.8590719172483514,
#   'długi': 2.0083677751889444,
#   'udręczyć': 2.9444389791664403,
#   'doprowadzić': 1.6916760106710724,
#   'czterdzieści': 1.729994874973209,
#   'sześć': 1.4944288036604423,
#   'silny': 0.5465437063680699,
#   'tęgi': 4.05629649458457,
#   'zagadać': 2.9444389791664403,
#   'bywać': 0.709166334192691,
#   'wyjeżdżać': 2.4793817738560304,
#   'petersburg': 2.9444389791664403,
#   'pilnować': 2.3053590198767706,
#   'testament': 3.6916533809966614,
#   'nieboszczka': 3.1162892360931,
#   'obalić': 2.028148247292285,
#   'wdzięczny': 1.8458266904983307,
#   'posiedzieć': 1.33500106673234,
#   'wiadomość': 1.33500106673234,
#   'zaraz': 0.8592512846332961,
#   'przyszlij': 2.2512917986064953,
#   'zachwycić': 2.2512917986064953,
#   'rychły': 2.538973871058276,
#   'orzeźwić': 2.2512917986064953,
#   'nabrać': 1.8590719172483514,
#   'nagadać': 2.2512917986064953,
#   'pełny': 0.23638877806423034,
#   'idealny': 1.8458266904983307,
#   'rekonwalescencja': 2.9444389791664403,
#   'zamienić': 2.8807231647803326,
#   'wychodzić': 1.0930874127361399,
#   'zachwycać': 1.4403615823901663,
#   'trafność': 2.9444389791664403,
#   'choroba': 1.072636802264849,
#   'apetyt': 2.2512917986064953,
#   'pokrzepiać': 2.9444389791664403,
#   'prędko': 0.9190646587568803,
#   'list': 2.702903297399117,
#   'spóźnić': 1.8458266904983307,
#   'epoka': 1.1526795099383853,
#   'wskazany': 2.2512917986064953,
#   'nadejść': 1.55814461804655,
#   'wiadomości': 1.33500106673234,
#   'śmieć': 1.1861274440059255,
#   'zainteresować': 1.6916760106710724,
#   'pachciarz': 2.9444389791664403,
#   'zasławka': 2.028148247292285,
#   'furman': 1.8590719172483514,
#   'prezesowy': 0.8649974374866045,
#   'niedawno': 0.8043728156701697,
#   'las': 1.2396908869280152,
#   'opisywać': 2.2512917986064953,
#   'koń': 0.9190646587568803,
#   'ożywić': 1.6916760106710724,
#   'handlować': 1.8458266904983307,
#   'jakoby': 2.538973871058276,
#   'kupić': 0.2821571965198112,
#   'nabój': 2.9444389791664403,
#   'zechcieć': 3.459989749946418,
#   'widocznie': 1.0930874127361399,
#   'szlangbaum': 12.980874791444654,
#   'żydek': 1.6916760106710724,
#   'ogłosić': 1.8458266904983307,
#   'nagroda': 1.8458266904983307,
#   'upatrywać': 2.028148247292285,
#   'bodajby': 3.1162892360931,
#   'mysi': 2.9444389791664403,
#   'tworzyć': 0.8649974374866045,
#   'pogłoska': 2.2512917986064953,
#   'wyjaśnieć': 1.8458266904983307,
#   'zupełnie': 0.2821571965198112,
#   'niepokoić': 3.2179104067945468,
#   'wzmóc': 2.538973871058276,
#   'istotny': 1.6916760106710724,
#   'trwoga': 1.55814461804655,
#   'wobec': 1.0930874127361399,
#   'ulegać': 1.33500106673234,
#   'rejent': 3.6916533809966614,
#   'zawezwać': 2.538973871058276,
#   'pokazać': 0.6418538861723947,
#   'zeznać': 2.9444389791664403,
#   'wyjazd': 3.718143834496703,
#   'formalny': 1.8458266904983307,
#   'rozporządzić': 5.077947742116552,
#   'pozostały': 4.05629649458457,
#   'siedemdziesiąt': 1.55814461804655,
#   'leżeć': 0.7589792434098074,
#   'osoba': 0.2702903297399117,
#   'obcy': 1.072636802264849,
#   'dowód': 0.5930637220029628,
#   'niepoczytalność': 2.9444389791664403,
#   'całkiem': 0.9295359586241757,
#   'testator': 2.9444389791664403,
#   'ogromny': 0.9161449486535458,
#   'helenka': 2.028148247292285,
#   'podzielić': 1.8458266904983307,
#   'swoić': 0.0,
#   'służba': 0.8649974374866045,
#   'mielić': 0.6931471805599453,
#   'sum': 1.4403615823901663,
#   'otrzymać': 1.1861274440059255,
#   'pięćset': 3.383352021342145,
#   'stolarzyć': 2.9444389791664403,
#   'dróżnik': 4.67443385413965,
#   'rzewny': 5.077947742116552,
#   'zapis': 9.229133452491654,
#   'zobowiązać': 2.028148247292285,
#   'ogłaszać': 2.538973871058276,
#   'akt': 2.028148247292285,
#   'posypać': 2.2512917986064953,
#   'obraz': 2.5949923124598135,
#   'wypowiedzieć': 1.33500106673234,
#   'prezent': 1.6916760106710724,
#   'córeczka': 2.028148247292285,
#   'piękny': 0.1410785982599056,
#   'stawska': 5.9911729806667635,
#   'uśmiech': 0.9190646587568803,
#   'przygryzać': 1.8458266904983307,
#   'obdarować': 2.538973871058276,
#   'zanotować': 2.538973871058276,
#   'nazwisko': 0.5930637220029628,
#   'przemawiać': 1.8458266904983307,
#   'bliski': 1.072636802264849,
#   'wnet': 0.8043728156701697,
#   'trafić': 1.2837077723447894,
#   'obudzić': 0.6418538861723947,
#   'iskra': 1.6916760106710724,
#   'nadzieja': 1.8590719172483514,
#   'wyjaśnić': 1.8458266904983307,
#   'dziwny': 1.0179947762061978,
#   'postępowanie': 1.55814461804655,
#   'zawiadomić': 1.55814461804655,
#   'przyjmować': 0.6418538861723947,
#   'gotówka': 1.4403615823901663,
#   'zastrzec': 2.538973871058276,
#   'nadto': 1.55814461804655,
#   'dać': 0.2821571965198112,
#   'kapitał': 2.2416432054906634,
#   'zamiana': 1.4403615823901663,
#   'płatnąć': 2.9444389791664403,
#   'hipoteka': 2.9444389791664403,
#   'wiejski': 1.8458266904983307,
#   'listopad': 2.538973871058276,
#   'stanowczo': 1.2396908869280152,
#   'objaśnić': 1.4403615823901663,
#   'osobisty': 1.6916760106710724,
#   'granica': 1.9970576602222545,
#   'zbierać': 0.9295359586241757,
#   'zapytywać': 2.8807231647803326,
#   'odkładać': 2.028148247292285,
#   'rozmowy': 1.2396908869280152,
#   'propozycja': 2.028148247292285,
#   'domówić': 2.538973871058276,
#   'tkwieć': 2.538973871058276,
#   'zejść': 0.5930637220029628,
#   'utrzymać': 1.1526795099383853,
#   'pomieszać': 2.538973871058276,
#   'rachunki': 0.9985288301111273,
#   'dowiadywać': 1.8458266904983307,
#   'paryż': 0.6418538861723947,
#   'sławny': 1.55814461804655,
#   'geista': 4.05629649458457,
#   'zdolny': 1.4403615823901663,
#   'akademia': 7.616921613174828,
#   'drwina': 2.538973871058276,
#   'mocno': 1.6748413394327402,
#   'zachwiać': 1.8458266904983307,
#   'francuski': 1.1526795099383853,
#   'oceniać': 2.028148247292285,
#   'wartość': 0.9985288301111273,
#   'metal': 2.2512917986064953,
#   'mędrzec': 2.538973871058276,
#   'geist': 2.2512917986064953,
#   'dokuczyć': 4.502583597212991,
#   'gramatyka': 2.9444389791664403,
#   'szkalować': 2.538973871058276,
#   'napomykać': 2.2512917986064953,
#   'wątpliwość': 2.028148247292285,
#   'rozjaśnić': 5.077947742116552,
#   'młody': 0.4727775561284607,
#   'spodziać': 2.538973871058276,
#   'minąć': 0.5465437063680699,
#   'rozmawiać': 0.5155507707799777,
#   'wahać': 0.9295359586241757,
#   'darowizna': 2.9444389791664403,
#   'wydawać': 0.4727775561284607,
#   'dzieciak': 2.538973871058276,
#   'oburzyć': 0.6931471805599453,
#   'zapisać': 1.2396908869280152,
#   'helcia': 2.538973871058276,
#   'polubić': 5.077947742116552,
#   'spokoić': 1.072636802264849,
#   'ciężki': 0.5930637220029628,
#   'nieco': 0.45953232937844013,
#   'mraczewski': 2.145273604529698,
#   'umarły': 2.9444389791664403,
#   'mraczewskiemu': 2.538973871058276,
#   'prawda': 0.9985288301111273,
#   'potrzebować': 0.3794896217049037,
#   'obawiać': 1.2396908869280152,
#   'wspomnieć': 3.217491262680679,
#   'kontent': 2.2512917986064953,
#   'nadawać': 1.6916760106710724,
#   'forma': 0.8043728156701697,
#   'umniejszyć': 2.9444389791664403,
#   'kłopot': 1.1526795099383853,
#   'ledwie': 0.2702903297399117,
#   'jedyny': 0.7472144018302211,
#   'notabene': 2.2512917986064953,
#   'układać': 1.2396908869280152,
#   'wystawa': 2.4793817738560304,
#   'zwykle': 0.6418538861723947,
#   'sobota': 5.077947742116552,
#   'lubić': 0.2702903297399117,
#   'umieścić': 0.8043728156701697,
#   'kantor': 2.2512917986064953,
#   'niewysoki': 2.9444389791664403,
#   'rzadki': 1.55814461804655,
#   'odwiedziny': 1.8458266904983307,
#   'wystarczyć': 1.9970576602222545,
#   'zorientować': 1.6916760106710724,
#   'zaszły': 1.4403615823901663,
#   'gruntowny': 2.9444389791664403,
#   'zmiana': 2.145273604529698,
#   'lubo': 1.55814461804655,
#   'pokaźny': 2.9444389791664403,
#   'zarazem': 0.8649974374866045,
#   'trocha': 0.16447619647394401,
#   'arogancki': 2.538973871058276,
#   'publiczność': 4.05629649458457,
#   'dopuszczać': 2.028148247292285,
#   'drobne': 1.8458266904983307,
#   'ujść': 2.2512917986064953,
#   'uwaga': 0.5020919437972361,
#   'inkasent': 2.028148247292285,
#   'dopuścić': 2.2512917986064953,
#   'malwersacja': 2.538973871058276,
#   'wszędzie': 1.33500106673234,
#   'zresztą': 0.24671429471091602,
#   'mina': 1.4944288036604423,
#   'drwić': 1.072636802264849,
#   'kraj': 0.8043728156701697,
#   'torba': 2.538973871058276,
#   'jednia': 1.8590719172483514,
#   'okpiwać': 2.9444389791664403,
#   'łapać': 1.8458266904983307,
#   'wolne': 2.2512917986064953,
#   'zaprzątać': 2.538973871058276,
#   'gospodarować': 4.502583597212991,
#   'dzieciństwo': 1.8458266904983307,
#   ...}}

# %%
for chapter_index, chapter_weights in tf_idf_weights.items():
    wc = WordCloud(width=800, height=400, background_color='white')
    wc.generate_from_frequencies(chapter_weights)
    wc.to_file(f"lalka/wordclouds/chapter_{chapter_index}.png")

# %%
def best_fitting_chapter(tf_idf_weights, word, topk):
    polish_morph = morfeusz2.Morfeusz()
    core_word = polish_morph.analyse(word)[0][2][1].lower()

    weights = {}
    for chapter_index, chapter_weights in tf_idf_weights.items():
        if core_word in chapter_weights:
            weights[chapter_index] = chapter_weights[core_word]
        else:
            weights[chapter_index] = 0

    top_weights = sorted(weights.items(), key=lambda x: x[1], reverse=True)
    
    return top_weights[:topk]

best_fitting_chapter(tf_idf_weights, "sklep", 5)
best_fitting_chapter(tf_idf_weights, "geist", 5)
# Out:
# [(22, 81.04650474983383),
#  (35, 15.759042590245468),
#  (37, 2.2512917986064953),
#  (0, 0),
#  (1, 0)]

# %%
def find_top_successors(all_words, target_word, topk):
    counts = {}
    for index, word in enumerate(all_words):
        if index + 1 < len(all_words):
            if word != target_word:
                continue

            successor = all_words[index + 1]
            counts[successor] = counts.get(successor, 0) + 1
    
    top_count = sorted(counts.items(), key=lambda x: x[1], reverse=True)

    return top_count[:topk]

top_successor = {}
for word in set(words_in_book):
    top_successor[word] = find_top_successors(words_in_book, word, 5)

top_successor
# Out:
# {'odwracać': [('głowa', 2),
#   ('matka', 1),
#   ('nałożyć', 1),
#   ('tyć', 1),
#   ('ażeby', 1)],
#  'zasługiwać': [('dawać', 1),
#   ('wysoki', 1),
#   ('myśleć', 1),
#   ('odeprzeć', 1),
#   ('nazywać', 1)],
#  'prezencik': [('dostać', 1)],
#  'swój': [('mieszkanie', 8),
#   ('wokulski', 6),
#   ('gabinet', 5),
#   ('towarzysz', 5),
#   ('mieć', 5)],
#  'żyć': [('znaczyć', 1),
#   ('łaska', 1),
#   ('wyssać', 1),
#   ('chcieć', 1),
#   ('zawołać', 1)],
#  'wczesny': [('plecy', 1), ('poradzić', 1), ('motyl', 1)],
#  'zawiązywać': [('towarzystwo', 1),
#   ('plac', 1),
#   ('spółka', 1),
#   ('stosunki', 1)],
#  'preparować': [('pamiętać', 1)],
#  'rześki': [('zwrócić', 1), ('wiatr', 1)],
#  'kręcić': [('głowa', 6),
#   ('mieszkać', 1),
#   ('łasić', 1),
#   ('myślić', 1),
#   ('sklep', 1)],
#  'staś': [('pisać', 1),
#   ('własny', 1),
#   ('dopiero', 1),
#   ('osiem', 1),
#   ('zamknąć', 1)],
#  'zwiędły': [('powtórzyć', 1)],
#  'twierdza': [('dzień', 1)],
#  'obniżyć': [('skalić', 1)],
#  'siać': [('niepochwytny', 1)],
#  'pora': [('robić', 1),
#   ('wytknąć', 1),
#   ('wyzwolić', 1),
#   ('zacząć', 1),
#   ('wypowiedzieć', 1)],
#  'podlizywać': [('chcieć', 1)],
#  'stalówka': [('wiadomo', 1)],
#  'minąć': [('złożyć', 1),
#   ('począć', 1),
#   ('pozwalać', 1),
#   ('przyjść', 1),
#   ('dług', 1)],
#  'sypiać': [('odziewać', 1), ('noc', 1), ('godzina', 1)],
#  'wlec': [('zaprzęgnąć', 1),
#   ('porównanie', 1),
#   ('ignacy', 1),
#   ('ociężały', 1),
#   ('siebie', 1)],
#  'przepych': [('zdeptać', 1)],
#  'wysługiwać': [('starość', 1)],
#  'karlsbadu': [('chwila', 1)],
#  'najemny': [('obrońca', 1)],
#  'tron': [('niemiecki', 1)],
#  'puls': [('bić', 3), ('kazać', 2), ('dziwić', 1), ('przejść', 1)],
#  'podwoj': [('dziesięć', 1)],
#  'żółwi': [('zresztą', 1)],
#  'dokuczać': [('dopóty', 1), ('subiekt', 1)],
#  'familijny': [('móc', 1)],
#  'niby': [('echo', 2),
#   ('wizerunek', 1),
#   ('cierpieć', 1),
#   ('trocha', 1),
#   ('postać', 1)],
#  'obawiać': [('bankructwo', 1),
#   ('jutro', 1),
#   ('krzyknąć', 1),
#   ('książę', 1),
#   ('tomasz', 1)],
#  'zastanowić': [('odeprzeć', 2),
#   ('wszakże', 2),
#   ('szkoda', 1),
#   ('męczyć', 1),
#   ('klęska', 1)],
#  'dumnie': [('patrzeć', 1), ('pocałować', 1), ('zrobić', 1), ('kazać', 1)],
#  'malwersacja': [('nabyć', 1), ('kilkadziesiąt', 1)],
#  'mikołaj': [('otworzyć', 4),
#   ('podać', 2),
#   ('robić', 1),
#   ('twardo', 1),
#   ('odziać', 1)],
#  'gdzieniegdzie': [('poplamić', 1),
#   ('wyskakiwać', 1),
#   ('odnajdować', 1),
#   ('środek', 1)],
#  'wysokość': [('drugie', 2),
#   ('cztery', 1),
#   ('uderzyć', 1),
#   ('dziesięć', 1),
#   ('pierwszy', 1)],
#  'szpigelmanowi': [('interes', 1)],
#  'cierpiący': [('odeprzeć', 1)],
#  'świeca': [('nikt', 1), ('płonąć', 1), ('woskowy', 1), ('nalać', 1)],
#  'migdał': [('lukrecja', 1)],
#  'odkrycie': [('wzruszyć', 1),
#   ('mniej', 1),
#   ('sześć', 1),
#   ('metal', 1),
#   ('suzin', 1)],
#  'posilać': [('radca', 1)],
#  'stanowczy': [('upadek', 1),
#   ('decyzja', 1),
#   ('prosty', 1),
#   ('ojciec', 1),
#   ('uprzedzić', 1)],
#  'wykarmić': [('rzucać', 1), ('ubogi', 1), ('cierpieć', 1)],
#  'tradycja': [('wiedzieć', 1)],
#  'zachodzić': [('soba', 1),
#   ('łza', 1),
#   ('patrzyć', 1),
#   ('pokój', 1),
#   ('człowiek', 1)],
#  'napoleonku': [('uczyć', 1)],
#  'cnotliwy': [('autor', 1), ('druga', 1)],
#  'podręcznik': [('grecki', 1)],
#  'obdzierać': [('przyszły', 1), ('potem', 1)],
#  'targać': [('ciotka', 1),
#   ('prosić', 1),
#   ('mruknąć', 1),
#   ('wiatr', 1),
#   ('plunąć', 1)],
#  'przyszlę': [('zaraz', 1)],
#  'ofuknąć': [('jednia', 1), ('podjąć', 1)],
#  'przylegać': [('szyja', 1)],
#  'marsz': [('rakoczy', 1), ('nieraz', 1), ('zrobić', 1), ('ramię', 1)],
#  'chrabąszcz': [('cicho', 1)],
#  'baranina': [('lord', 2), ('ryż', 1)],
#  'chodzić': [('pokój', 8),
#   ('powrót', 3),
#   ('sklep', 2),
#   ('myśleć', 2),
#   ('pokazać', 2)],
#  'bycie': [('pozostać', 1)],
#  'zwrócić': [('uwaga', 7),
#   ('siebie', 4),
#   ('wokulski', 4),
#   ('pieniądz', 3),
#   ('panna', 2)],
#  'grudzień': [('mieć', 2),
#   ('rok', 2),
#   ('turek', 1),
#   ('wybuchły', 1),
#   ('austria', 1)],
#  'wzorować': [('angielski', 1)],
#  'ulica': [('wokulski', 3),
#   ('mówić', 3),
#   ('wysadzić', 3),
#   ('gładki', 2),
#   ('stać', 2)],
#  'owacja': [('rossiego', 2), ('spotykać', 1), ('mieć', 1), ('paciorek', 1)],
#  'poznawać': [('dosyć', 1),
#   ('ulica', 1),
#   ('płakać', 1),
#   ('stare', 1),
#   ('łęcki', 1)],
#  'bezczelny': [('ubóstwo', 1), ('zaloty', 1), ('swój', 1), ('śmiać', 1)],
#  'zasłużony': [('tomasz', 1)],
#  'wywiązać': [('awantura', 1)],
#  'cwałować': [('dźwigać', 1), ('tedy', 1)],
#  'kolerowej': [('powiedzieć', 1)],
#  'wydziedziczyć': [('mima', 1), ('gadać', 1)],
#  'sympatia': [('cierpienie', 1),
#   ('okazować', 1),
#   ('zapomnieć', 1),
#   ('maluczki', 1),
#   ('wzgląd', 1)],
#  'sztora': [('lokal', 1)],
#  'heloiza': [('romansować', 1)],
#  'zdecydowany': [('wyjść', 1), ('dziewięćdziesiąt', 1), ('skończyć', 1)],
#  'zgoda': [('plunąć', 1), ('tomasz', 1), ('rzec', 1)],
#  'szperlingowa': [('tysiąc', 1), ('piękny', 1)],
#  'poplątać': [('szyk', 1)],
#  'wizytować': [('współczuć', 1), ('składać', 1), ('wyróżnić', 1)],
#  'skroić': [('cienki', 1)],
#  'cecha': [('umysł', 1), ('mówić', 1), ('urodzić', 1)],
#  'skruszyć': [('młot', 1)],
#  'szorstki': [('odpowiedź', 1),
#   ('koniec', 1),
#   ('styl', 1),
#   ('grzeczności', 1),
#   ('ponur', 1)],
#  'dwutygodniowy': [('praca', 1)],
#  'emocja': [('zawołać', 1)],
#  'morderstwo': [('król', 1)],
#  'moc': [('człowiek', 1),
#   ('szlangbaum', 1),
#   ('poświęcić', 1),
#   ('kochać', 1),
#   ('maleska', 1)],
#  'skrzypek': [('powtórzyć', 1),
#   ('spotykać', 1),
#   ('stracić', 1),
#   ('pospolity', 1)],
#  'niedogodność': [('umowa', 1)],
#  'parskać': [('wiekowy', 1), ('wyrzucać', 1), ('domiar', 1), ('deptać', 1)],
#  'postanowić': [('zrobić', 3),
#   ('traktować', 2),
#   ('soba', 2),
#   ('powrót', 1),
#   ('wejść', 1)],
#  'cierpieć': [('wcale', 1),
#   ('ścierać', 1),
#   ('choroba', 1),
#   ('łatwo', 1),
#   ('nieszczęśliwy', 1)],
#  'młody': [('człowiek', 41),
#   ('chłopak', 4),
#   ('mężatka', 3),
#   ('mieć', 2),
#   ('stary', 2)],
#  'gospodarować': [('pryncypał', 1),
#   ('dobra', 1),
#   ('gospodarować', 1),
#   ('wspomnieć', 1)],
#  'epizod': [('życie', 1), ('przemówienie', 1)],
#  'kłuć': [('krzyczeć', 1), ('wyraz', 1)],
#  'konsument': [('tani', 1), ('pomyśleć', 1)],
#  'łata': [('bóg', 1)],
#  'zwiedzić': [('ażeby', 1), ('stan', 1)],
#  'oszczerstwo': [('pójść', 1), ('lekceważenie', 1)],
#  'pozować': [('ciotka', 1),
#   ('upadły', 1),
#   ('istota', 1),
#   ('nosić', 1),
#   ('kolej', 1)],
#  'niegdyś': [('obecnie', 2),
#   ('wielki', 1),
#   ('szczotkarz', 1),
#   ('maria', 1),
#   ('dostarczać', 1)],
#  'niejednokrotnie': [('powód', 1),
#   ('wokulski', 1),
#   ('złożyć', 1),
#   ('bezwładny', 1)],
#  'ruski': [('tkanina', 1), ('chryste', 1), ('szlangbaum', 1)],
#  'ląd': [('łańcuch', 1)],
#  'zakłopotany': [('wokulski', 1),
#   ('zrobić', 1),
#   ('spokój', 1),
#   ('minąć', 1),
#   ('tomasz', 1)],
#  'rysunek': [('dom', 1)],
#  'niżeli': [('modlić', 1), ('chłodny', 1)],
#  'siec': [('deszcz', 1)],
#  'bankierski': [('przytulić', 1), ('srebro', 1), ('chcieć', 1)],
#  'naturalnie': [('wtrącić', 2),
#   ('zatrzeć', 1),
#   ('prawić', 1),
#   ('wybrać', 1),
#   ('ignacy', 1)],
#  'kremowy': [('suknia', 2), ('barwy', 1)],
#  'straż': [('interes', 1), ('polewać', 1), ('iść', 1), ('przerwać', 1)],
#  'migrena': [('powinny', 1), ('musieć', 1)],
#  'świegot': [('sztuczny', 1), ('wróbel', 1)],
#  'wydostać': [('mokotowski', 1)],
#  'zlękły': [('słowić', 1), ('swój', 1)],
#  'tenor': [('akompaniament', 1)],
#  'schodki': [('wiodący', 1)],
#  'amatorstwo': [('obsługiwać', 1), ('jechać', 1)],
#  'przewijać': [('niektóry', 1)],
#  'utytułowany': [('traktować', 1), ('najmniej', 1)],
#  'próżnować': [('skrzywić', 1), ('arystokracja', 1)],
#  'drwiący': [('jakżem', 1), ('mieć', 1), ('ton', 1)],
#  'wsunąć': [('ręka', 4), ('palec', 1), ('spuścić', 1)],
#  'przebudzić': [('niekiedy', 1)],
#  'sprzedaj': [('suma', 1),
#   ('niedziela', 1),
#   ('jedyny', 1),
#   ('kamienica', 1),
#   ('człowiek', 1)],
#  'rzeźbiarz': [('wspólny', 1)],
#  'szpilka': [('pozwolić', 1),
#   ('zwyczaj', 1),
#   ('musieć', 1),
#   ('przesiadywać', 1),
#   ('przelewać', 1)],
#  'parsknąć': [('króciutki', 1)],
#  'hojność': [('spodziewać', 1)],
#  'warsztat': [('żyć', 1), ('mieszkanie', 1), ('ulica', 1)],
#  'węgrzyn': [('obiad', 1), ('małgorzata', 1)],
#  'wódka': [('położyć', 1), ('łobuz', 1)],
#  'przeniknąć': [('przykuć', 1)],
#  'osłupienie': [('przyjść', 1)],
#  'rewirowy': [('mieszkanie', 1),
#   ('baronowy', 1),
#   ('wziąć', 1),
#   ('siedzieć', 1),
#   ('mieć', 1)],
#  'torować': [('soba', 1)],
#  'posażny': [('wydobycie', 1)],
#  'występować': [('silny', 1),
#   ('plac', 1),
#   ('chorobliwy', 1),
#   ('pretensja', 1),
#   ('żywy', 1)],
#  'zaoponować': [('torba', 1)],
#  'postępować': [('zaprzysięgać', 1),
#   ('nietaktownie', 1),
#   ('przejawiać', 1),
#   ('ażeby', 1),
#   ('znaleźć', 1)],
#  'urodziwy': [('spytać', 1)],
#  'szaleć': [('burza', 1),
#   ('ukłonić', 1),
#   ('naprawdę', 1),
#   ('joasia', 1),
#   ('babcia', 1)],
#  'lipowy': [('aleja', 1), ('wokulski', 1)],
#  'przypuszczać': [('możliwości', 1), ('pewny', 1), ('odeprzeć', 1)],
#  'ścierka': [('rzucić', 1)],
#  'uciosać': [('garson', 1)],
#  'ujeżdżacz': [('pogromca', 1)],
#  'zamajaczyć': [('blask', 1)],
#  'zastawić': [('ciąg', 1)],
#  'niezmienny': [('geist', 1)],
#  'zarysowywać': [('tomasz', 1),
#   ('projekt', 1),
#   ('mama', 1),
#   ('wokulski', 1),
#   ('dokładnie', 1)],
#  'wrota': [('mieć', 1)],
#  'oboźna': [('ciąg', 1)],
#  'wstręt': [('małżeństwo', 1),
#   ('pójść', 1),
#   ('łącznik', 1),
#   ('własny', 1),
#   ('tyli', 1)],
#  'oduczyć': [('wyzywać', 1), ('swój', 1)],
#  'nagradzający': [('zaraz', 1), ('uderzyć', 1)],
#  'odlać': [('osiem', 1)],
#  'załatwiać': [('zwracać', 1), ('móc', 1), ('interesant', 1), ('interes', 1)],
#  'uderzenie': [('kij', 1),
#   ('topór', 1),
#   ('zaszumiać', 1),
#   ('dzwonka', 1),
#   ('stach', 1)],
#  'okropność': [('nędzny', 1), ('zresztą', 1)],
#  'czciciel': [('odezwać', 1)],
#  'indagować': [('sprzedać', 1)],
#  'nabój': [('głupstwo', 1)],
#  'gody': [('mieć', 1), ('musieć', 1)],
#  'opat': [('jouve', 2), ('chcieć', 1)],
#  'usłyszeć': [('głos', 3),
#   ('siebie', 2),
#   ('charakterystyczny', 2),
#   ('doznać', 2),
#   ('wyrok', 2)],
#  'przywyknąć': [('stary', 1),
#   ('wino', 1),
#   ('swój', 1),
#   ('podobny', 1),
#   ('odciąć', 1)],
#  'termin': [('wyjazd', 1), ('przyjść', 1), ('pójść', 1), ('wokulski', 1)],
#  'stalić': [('zwrócić', 1), ('pojedynczo', 1), ('tragarz', 1), ('wysoce', 1)],
#  'tandeciarz': [('podobny', 1)],
#  'plewny': [('bywać', 1)],
#  'poprzeczny': [('formować', 1), ('dzienić', 1)],
#  'gardzić': [('serce', 1),
#   ('chwila', 1),
#   ('reszta', 1),
#   ('magnat', 1),
#   ('arystokracja', 1)],
#  'projekt': [('zdradzać', 1),
#   ('snuć', 1),
#   ('wywołać', 1),
#   ('pański', 1),
#   ('dotyczyć', 1)],
#  'rogatka': [('utworzyć', 1), ('wokulski', 1)],
#  'zezwalać': [('sprzedaż', 1)],
#  'siekiera': [('garść', 2)],
#  'akurat': [('tyli', 3),
#   ('zostać', 1),
#   ('pisać', 1),
#   ('łóżko', 1),
#   ('mądry', 1)],
#  'niedostrzegalny': [('jednać', 1)],
#  'uprzejmość': [('szuman', 1), ('miłostka', 1)],
#  'naładować': [('gorczyca', 1),
#   ('wysokość', 1),
#   ('podróżny', 1),
#   ('kieszenia', 1)],
#  'chwileczka': [('zabrać', 1)],
#  'poniżać': [('wartość', 1), ('mężczyzna', 1)],
#  'cklić': [('późnić', 1)],
#  'młotek': [('zielony', 1)],
#  'odrębny': [('język', 1)],
#  'spokój': [('przypuścić', 1),
#   ('niezachwiany', 1),
#   ('natura', 1),
#   ('zacny', 1),
#   ('ojciec', 1)],
#  'funt': [('funt', 1), ('grosz', 1), ('mężowski', 1), ('ignacy', 1)],
#  'ukraść': [('czterysta', 1), ('tamten', 1), ('magiel', 1), ('lalka', 1)],
#  'renta': [('tytuł', 1)],
#  'taksować': [('wokulski', 1), ('niebo', 1)],
#  'wszelako': [('zgroza', 1)],
#  'rozgrzać': [('wokulski', 1)],
#  'obcisły': [('spodnie', 2), ('wojskowy', 1), ('strój', 1), ('kształty', 1)],
#  'doprowadzać': [('baba', 1)],
#  'znajdziem': [('inżynier', 1)],
#  'kipieć': [('gniew', 1),
#   ('śmiech', 1),
#   ('pluskać', 1),
#   ('wokulski', 1),
#   ('rozsądek', 1)],
#  'bank': [('osiemset', 1),
#   ('niski', 1),
#   ('dziewięćdziesiąt', 1),
#   ('mama', 1),
#   ('lewo', 1)],
#  'zapowiedź': [('nadchodzić', 1), ('powiedzieć', 1)],
#  'ustępować': [('drogi', 1),
#   ('przejść', 1),
#   ('serce', 1),
#   ('dopiero', 1),
#   ('kochać', 1)],
#  'gołąb': [('wychodzić', 1)],
#  'trybunał': [('lepsza', 1)],
#  'okręcić': [('szanowny', 1), ('chustka', 1)],
#  'zamoście': [('bawić', 1)],
#  'zlew': [('trzy', 1)],
#  'podczesać': [('mieć', 1)],
#  'przygotowawczy': [('machina', 1)],
#  'stado': [('chwila', 1),
#   ('armata', 1),
#   ('owca', 1),
#   ('iść', 1),
#   ('rzucać', 1)],
#  'zdolny': [('bawić', 1),
#   ('zaufany', 1),
#   ('uczyć', 1),
#   ('pracować', 1),
#   ('przyjmować', 1)],
#  'mocny': [('rumieniec', 2),
#   ('dotknąć', 1),
#   ('przewidywanie', 1),
#   ('zimny', 1),
#   ('ostateczny', 1)],
#  'rozsadzać': [('ignacy', 1), ('dama', 1)],
#  'medalion': [('otworzyć', 1), ('panna', 1), ('przyjść', 1), ('drwić', 1)],
#  'dzikus': [('walić', 1)],
#  'szkatułka': [('nastąpić', 1)],
#  'postąpić': [('baron', 2),
#   ('nastręczać', 1),
#   ('najwyżej', 1),
#   ('piękny', 1),
#   ('wokulski', 1)],
#  'obrót': [('lewo', 2),
#   ('ramię', 1),
#   ('zazdrościć', 1),
#   ('żegnać', 1),
#   ('iść', 1)],
#  'ogroda': [('botaniczny', 2),
#   ('aklimatyzacyjny', 1),
#   ('zdjąć', 1),
#   ('chałupa', 1),
#   ('powrócić', 1)],
#  'zarzynać': [('naprawdę', 1)],
#  'wiecież': [('mówić', 1)],
#  'czynność': [('jutro', 1), ('pryncypał', 1), ('długi', 1), ('drzwi', 1)],
#  'wołyń': [('mówić', 1)],
#  'lampa': [('elektryczny', 3),
#   ('zielony', 3),
#   ('zima', 1),
#   ('przepuścić', 1),
#   ('papać', 1)],
#  'kolej': [('odebrać', 1),
#   ('łęcki', 1),
#   ('biedny', 1),
#   ('zbliżyć', 1),
#   ('pensja', 1)],
#  'willa': [('przytułek', 1), ('nazwać', 1)],
#  'polubić': [('jana', 1), ('polubić', 1), ('dom', 1)],
#  'nadarzać': [('tracić', 1)],
#  'dobranoc': [('upadać', 1), ('mówić', 1), ('powiedzieć', 1)],
#  'bodajże': [('rok', 1), ('tamten', 1), ('umizgać', 1)],
#  'magnat': [('odepchnąć', 1),
#   ('dać', 1),
#   ('obudzić', 1),
#   ('bawić', 1),
#   ('raczy', 1)],
#  'strusi': [('pierwszy', 1), ('żegnać', 1)],
#  'dunaj': [('mieć', 1), ('trwać', 1)],
#  'porobić': [('duha', 3),
#   ('dziad', 1),
#   ('synowiec', 1),
#   ('udogodnić', 1),
#   ('wielki', 1)],
#  'zmieszać': [('uśmiechnąć', 2),
#   ('wysoki', 1),
#   ('ażeby', 1),
#   ('rzec', 1),
#   ('przechodzień', 1)],
#  'rozpierzchły': [('głąb', 1)],
#  'jednoroczny': [('dochód', 1)],
#  'figura': [('ignacy', 1),
#   ('ruchomy', 1),
#   ('krótko', 1),
#   ('wydawać', 1),
#   ('mówić', 1)],
#  'dzwonić': [('drugi', 1),
#   ('mieszkanie', 1),
#   ('podróżny', 1),
#   ('oko', 1),
#   ('posłać', 1)],
#  'wnuczka': [('pamiętać', 1),
#   ('jednać', 1),
#   ('nieboszczka', 1),
#   ('psubrat', 1)],
#  'budzić': [('chwila', 1),
#   ('wydobywać', 1),
#   ('ojciec', 1),
#   ('szmer', 1),
#   ('natura', 1)],
#  'marnie': [('jazda', 1)],
#  'palmieriego': [('zapłacić', 1)],
#  'kolonialny': [('wydawać', 1), ('stary', 1)],
#  'noga': [('nieco', 2),
#   ('postać', 2),
#   ('oprzeć', 2),
#   ('brudny', 2),
#   ('gęsty', 1)],
#  'wykazać': [('dzwonek', 1)],
#  'popularność': [('wypić', 1)],
#  'pokręcić': [('szlangbaum', 1),
#   ('właściciel', 1),
#   ('sklep', 1),
#   ('cudny', 1),
#   ('stawska', 1)],
#  'zdruzgotać': [('przyjść', 1), ('nagle', 1)],
#  'zjeść': [('obiad', 1),
#   ('wynosić', 1),
#   ('łyżka', 1),
#   ('piec', 1),
#   ('elegancki', 1)],
#  'zadymić': [('zgrzytnąć', 1)],
#  'materia': [('niebieski', 1), ('zaczynać', 1)],
#  'zarabiać': [('histeryczka', 1), ('wyścigowy', 1), ('piętnaście', 1)],
#  'zamierać': [('człowiek', 1), ('wszelki', 1)],
#  'odezw': [('liptak', 1), ('kundel', 1), ('ułomna', 1)],
#  'niedołęga': [('mruknąć', 1), ('maruszewicz', 1)],
#  'ostrzyc': [('głowa', 1), ('śniady', 1), ('uczesać', 1), ('łeb', 1)],
#  'zakrzepły': [('woda', 1)],
#  'zadatek': [('sędzia', 1), ('wydać', 1)],
#  'miejsce': [('zajmować', 2),
#   ('panna', 2),
#   ('znaleźć', 2),
#   ('święty', 2),
#   ('ożenić', 1)],
#  'dudek': [('strzelać', 1)],
#  'chemik': [('wziąć', 1), ('razem', 1)],
#  'zaszczytny': [('oba', 1), ('stanowisko', 1)],
#  'bok': [('uśmiechnąć', 1),
#   ('odeprzeć', 1),
#   ('razem', 1),
#   ('stać', 1),
#   ('przylecieć', 1)],
#  'szuflada': [('wciskać', 1),
#   ('sklep', 1),
#   ('parasol', 1),
#   ('wydobywać', 1),
#   ('środek', 1)],
#  'przesadnia': [('kobieta', 1)],
#  'pobudzać': [('cena', 1)],
#  'muzeum': [('cluny', 1), ('istnieć', 1), ('praca', 1)],
#  'królestwo': [('uczony', 1), ('niebieski', 1)],
#  'targ': [('dwadzieścia', 1),
#   ('przeciągnąć', 1),
#   ('sklep', 1),
#   ('złoty', 1),
#   ('strona', 1)],
#  'szczerozłoty': [('jaka', 1)],
#  'brzydzić': [('uznać', 1)],
#  'litościwy': [('życie', 1), ('niewiasta', 1)],
#  'pozostać': [('smutny', 1),
#   ('kompletnie', 1),
#   ('kolega', 1),
#   ('naczelnik', 1),
#   ('siadać', 1)],
#  'kuchenny': [('myśleć', 1), ('obrachować', 1)],
#  'pełnieć': [('fikcyjny', 1), ('kapitał', 1)],
#  'korki': [('wreszcie', 1), ('wypchać', 1)],
#  'główny': [('drzwi', 2),
#   ('korpus', 1),
#   ('waga', 1),
#   ('odbyć', 1),
#   ('prowadzić', 1)],
#  'opłata': [('zapytać', 1)],
#  'namawiać': [('ażeby', 6),
#   ('powierzyć', 1),
#   ('ułożyć', 1),
#   ('przyjść', 1),
#   ('stare', 1)],
#  'dalibóg': [('mniej', 1), ('zarumienić', 1)],
#  'zupełny': [('wypić', 1),
#   ('triumf', 1),
#   ('ażeby', 1),
#   ('brak', 1),
#   ('bywać', 1)],
#  'zapewniać': [('zabraknąć', 1),
#   ('rozumieć', 1),
#   ('wydać', 1),
#   ('salon', 1),
#   ('łatwie', 1)],
#  'kasjer': [('zapewniać', 1)],
#  'umykać': [('błyskawica', 1), ('imię', 1), ('cień', 1), ('stąd', 1)],
#  'upartość': [('henryka', 1)],
#  'konsekwencja': [('hrabia', 1)],
#  'kolosalny': [('zresztą', 1)],
#  'nuda': [('móc', 1), ('grywać', 1), ('setka', 1), ('oddać', 1)],
#  'arogant': [('dawno', 1)],
#  'mienić': [('siedzieć', 1),
#   ('barwny', 1),
#   ('śmiać', 1),
#   ('potnieć', 1),
#   ('herbata', 1)],
#  'chcze': [('gadać', 1)],
#  'zatrucie': [('szczęście', 1)],
#  'chociażeś': [('dziadek', 1)],
#  'wygalonować': [('dama', 1)],
#  'pług': [('zmartwieć', 1), ('wolny', 1)],
#  'chłód': [('usiłować', 1),
#   ('dodać', 1),
#   ('nóż', 1),
#   ('wydrzeć', 1),
#   ('zamiast', 1)],
#  'parawan': [('siebie', 1)],
#  'parować': [('wtem', 1)],
#  'wybitny': [('osobistość', 1)],
#  'dziwactwo': [('baronowy', 1), ('nazywać', 1)],
#  'marszałkowski': [('braknąć', 1)],
#  'podbić': [('cena', 3), ('serce', 1), ('brzydko', 1)],
#  'krzepić': [('pościć', 1)],
#  'młodu': [('starość', 1),
#   ('późno', 1),
#   ('wysługiwać', 1),
#   ('mówić', 1),
#   ('lekceważyć', 1)],
#  'pomyśleć': [('wokulski', 14),
#   ('chwila', 3),
#   ('panna', 2),
#   ('dodać', 2),
#   ('jednocześnie', 2)],
#  'dzbanuszek': [('meine', 1)],
#  'blady': [('gniew', 2),
#   ('wosk', 1),
#   ('połysk', 1),
#   ('dotknąć', 1),
#   ('klejn', 1)],
#  'jakże': [('zapytać', 2),
#   ('miewać', 2),
#   ('sklep', 1),
#   ('zdawać', 1),
#   ('zaraz', 1)],
#  'posłannictwo': [('leon', 1)],
#  'policzyć': [('karb', 2), ('swój', 1)],
#  'zaloty': [('dostać', 1)],
#  'posiadacz': [('kamienica', 1), ('bawić', 1)],
#  'wychować': [('daleki', 1),
#   ('matka', 1),
#   ('robić', 1),
#   ('cierpieć', 1),
#   ('zaręczyć', 1)],
#  'wizyta': [('wokulski', 2),
#   ('panna', 2),
#   ('rewizyta', 1),
#   ('pogodzić', 1),
#   ('wielki', 1)],
#  'przebicie': [('leżący', 1)],
#  'luboczka': [('mówić', 1)],
#  'wyglancować': [('para', 1)],
#  'zdumienie': [('wieczór', 1),
#   ('niektóry', 1),
#   ('pytać', 1),
#   ('rossiego', 1),
#   ('cud', 1)],
#  'hasło': [('rzucić', 1), ('śpieszyć', 1)],
#  'żniwa': [('wojna', 1)],
#  'kępa': [('stary', 2),
#   ('las', 1),
#   ('wiejski', 1),
#   ('drzewo', 1),
#   ('grupa', 1)],
#  'raczek': [('ożenić', 2),
#   ('domański', 2),
#   ('pluć', 1),
#   ('odwiedzać', 1),
#   ('pokiwać', 1)],
#  'lesisty': [('okno', 1)],
#  'niechętnie': [('machać', 1), ('objaśniać', 1), ('zwrócić', 1)],
#  'klasyczny': [('spojrzeć', 1)],
#  'stolica': [('mętny', 1), ('świat', 1), ('zrobić', 1)],
#  'lipcowy': [('wiatr', 1), ('upał', 1), ('wnętrze', 1), ('plac', 1)],
#  'wcześnie': [('ażeby', 1),
#   ('tymczasem', 1),
#   ('chwila', 1),
#   ('rzec', 1),
#   ('umrzeć', 1)],
#  'brak': [('oddech', 2),
#   ('myśleć', 1),
#   ('znaleźć', 1),
#   ('odeprzeć', 1),
#   ('unieść', 1)],
#  'pot': [('czoło', 1)],
#  'nabijać': [('karabin', 1), ('broń', 1), ('kieszenia', 1)],
#  'sprzykrzyć': [('mąż', 1), ('stary', 1)],
#  'ukłucie': [('późno', 1)],
#  'odjechać': [('wokulski', 1), ('ziemia', 1)],
#  'dopiero': [('wokulski', 7),
#   ('chwila', 6),
#   ('przekonać', 4),
#   ('przypomnieć', 3),
#   ('panna', 3)],
#  'mod': [('siadać', 1), ('podać', 1), ('przyjaciel', 1)],
#  'grecki': [('wielki', 1),
#   ('pomyśleć', 1),
#   ('łaciński', 1),
#   ('litera', 1),
#   ('odpowiedź', 1)],
#  'niepotrzebnieś': [('pamiętać', 1)],
#  'zamyśleć': [('kiwać', 1), ('ostateczny', 1)],
#  'głowić': [('potem', 1), ('owinąć', 1)],
#  'drożyć': [('nieznośny', 1)],
#  'luk': [('męczyć', 1)],
#  'usprawiedliwiać': [('ekscentryczność', 1), ('niespodziewany', 1)],
#  'poddanie': [('bezgraniczny', 1)],
#  'rozlany': [('twarz', 1)],
#  'kramik': [('wokulski', 1), ('dopiero', 1)],
#  'kundmanka': [('trafiać', 1)],
#  'przestawić': [('litera', 1)],
#  'wielbiciel': [('córka', 1),
#   ('ciekawy', 1),
#   ('wabić', 1),
#   ('przykro', 1),
#   ('wtrącić', 1)],
#  'wytropić': [('tajemny', 1)],
#  'alboż': [('mniej', 1),
#   ('chcieć', 1),
#   ('spotkać', 1),
#   ('dawno', 1),
#   ('meliton', 1)],
#  'walka': [('czas', 1),
#   ('mieć', 1),
#   ('pomiędzy', 1),
#   ('fundamentalny', 1),
#   ('możliwy', 1)],
#  'biegła': [('sypialnia', 1),
#   ('wiorsta', 1),
#   ('osobliwie', 1),
#   ('małgorzata', 1),
#   ('zobaczyć', 1)],
#  'krowa': [('orzeł', 1), ('poznawać', 1), ('zaraz', 1), ('quichot', 1)],
#  'oryginał': [('lud', 1), ('robić', 1)],
#  'pleść': [('nienawidzieć', 1)],
#  'niepodobny': [('mylić', 1),
#   ('wybierać', 1),
#   ('świat', 1),
#   ('para', 1),
#   ('określić', 1)],
#  'utrzymać': [('dom', 3),
#   ('swój', 2),
#   ('binokle', 1),
#   ('wydobyć', 1),
#   ('jaśnie', 1)],
#  'brązy': [('stojący', 1)],
#  'sprawiedliwy': [('silnia', 1)],
#  'chrzestny': [('prezesowy', 1)],
#  'nawarzyć': [('piwo', 2)],
#  'karmia': [('fartuch', 1)],
#  'ościsty': [('jeść', 1)],
#  'obstalunek': [('dziesięć', 1)],
#  'protektor': [('krajowy', 1)],
#  'pobożnie': [('ściskać', 1), ('ręka', 1)],
#  'użycie': [('bezpośredni', 1)],
#  'forma': [('panna', 1),
#   ('fałd', 1),
#   ('dziesięć', 1),
#   ('suknia', 1),
#   ('pytać', 1)],
#  'czego': [('chcieć', 4),
#   ('soba', 3),
#   ('zapytać', 3),
#   ('stach', 2),
#   ('móc', 2)],
#  'wielkopański': [('zabawa', 1), ('chcieć', 1)],
#  'klapa': [('wytrzeć', 1),
#   ('frak', 1),
#   ('dżentelmen', 1),
#   ('czas', 1),
#   ('proponować', 1)],
#  'ubyć': [('przerwać', 1),
#   ('czterdzieści', 1),
#   ('zostać', 1),
#   ('straszny', 1)],
#  'stały': [('bawić', 1)],
#  'atletyczny': [('koń', 1)],
#  'ciosowy': [('ciżba', 1)],
#  'pocieszenie': [('ledwie', 1)],
#  'niebieski': [('barchanowy', 1),
#   ('kutasik', 1),
#   ('otrzymywać', 1),
#   ('szlafroczek', 1),
#   ('pies', 1)],
#  'wstrzymać': [('pewny', 1)],
#  'zapisany': [('zapisany', 1), ('ciągle', 1)],
#  'donosić': [('móc', 1),
#   ('czekać', 1),
#   ('sklep', 1),
#   ('ślub', 1),
#   ('zajechać', 1)],
#  'rozpłakać': [('odezwać', 1),
#   ('wszak', 1),
#   ('chwila', 1),
#   ('pierwszy', 1),
#   ('wokulski', 1)],
#  'mraczewskiego': [('dopiero', 1),
#   ('doświadczać', 1),
#   ('zapakować', 1),
#   ('zrobić', 1),
#   ('ażeby', 1)],
#  'nasunąć': [('świat', 1), ('dziwny', 1), ('kapelusz', 1), ('poezja', 1)],
#  'majątek': [('móc', 2),
#   ('zapisać', 2),
#   ('zwrócić', 2),
#   ('ziemski', 2),
#   ('praca', 2)],
#  'dodać': [('chwila', 10),
#   ('patrzeć', 7),
#   ('wokulski', 4),
#   ('śmieć', 4),
#   ('cicho', 4)],
#  'spragniony': [('cofać', 1)],
#  'przeceniać': [('mówić', 1), ('zasług', 1)],
#  'julian': [('wkraczać', 1)],
#  'zasłonić': [('twarz', 4),
#   ('usta', 1),
#   ('spod', 1),
#   ('chociaż', 1),
#   ('poła', 1)],
#  'jedwabny': [('sprzedaj', 1),
#   ('sukienka', 1),
#   ('kitel', 1),
#   ('rozpływać', 1),
#   ('móc', 1)],
#  'inżynier': [('swój', 1),
#   ('kolejowy', 1),
#   ('przeciągnąć', 1),
#   ('ciągle', 1),
#   ('ruina', 1)],
#  'pojawiać': [('piętrowy', 1), ('drobny', 1)],
#  'brunetka': [('przypatrywać', 1)],
#  'cięgi': [('aniżeli', 1)],
#  'nosio': [('stać', 1), ('zacząć', 1)],
#  'zawiadamiać': [('dzień', 1), ('druga', 1)],
#  'rozmyślić': [('dom', 1), ('kazać', 1), ('moskwa', 1)],
#  'bełkotać': [('blady', 1)],
#  'suknia': [('wielki', 2),
#   ('panna', 2),
#   ('sześć', 1),
#   ('wytarzać', 1),
#   ('kosztowny', 1)],
#  'zaspokoić': [('przerwać', 1), ('ciekawość', 1)],
#  'podrzeć': [('zdawać', 1),
#   ('pamiętać', 1),
#   ('gazeta', 1),
#   ('papierek', 1),
#   ('móc', 1)],
#  'zgłoszenie': [('konkurent', 1)],
#  'pociemnieć': [('wyobrazić', 1),
#   ('książę', 1),
#   ('jasnozielony', 1),
#   ('licytacja', 1),
#   ('chcieć', 1)],
#  'opoka': [('wypalać', 1)],
#  'uregulować': [('rachunki', 2),
#   ('należny', 1),
#   ('dużać', 1),
#   ('finanse', 1),
#   ('pewno', 1)],
#  'zachwycić': [('odwaga', 1), ('rzec', 1), ('chociaż', 1)],
#  'afganistan': [('grudzień', 1)],
#  'odpokutować': [('śmierć', 1), ('zbawić', 1)],
#  'rosół': [('wyobrazić', 1), ('potem', 1), ('pilić', 1)],
#  'ofiarowywać': [('pięć', 2), ('swój', 1), ('dorożkarz', 1)],
#  'przyjmować': [('udział', 2),
#   ('nowy', 2),
#   ('siebie', 2),
#   ('para', 2),
#   ('spytać', 1)],
#  'mniejszyć': [('dochód', 1), ('wstręt', 1)],
#  'giętki': [('uśmiechać', 1)],
#  'kieliszek': [('wina', 3),
#   ('mocno', 1),
#   ('rzucić', 1),
#   ('ażeby', 1),
#   ('anyżówka', 1)],
#  'odtąd': [('marzyć', 1),
#   ('nawiedzać', 1),
#   ('serce', 1),
#   ('pamiętać', 1),
#   ('wszystek', 1)],
#  'leczyć': [('darmo', 1),
#   ('tyli', 1),
#   ('zapytać', 1),
#   ('cudze', 1),
#   ('ideał', 1)],
#  'kryminał': [('wygrzebać', 1), ('siedzieć', 1)],
#  'upojenie': [('wylatywać', 1)],
#  'romantyczny': [('tymczasem', 1)],
#  'sprzymierzeniec': [('osoba', 1),
#   ('słyszeć', 1),
#   ('piękno', 1),
#   ('pozwolić', 1)],
#  'kolano': [('zamiast', 1),
#   ('wznosić', 1),
#   ('poradzić', 1),
#   ('antresola', 1),
#   ('siedzieć', 1)],
#  'rozsyłać': [('dopóki', 1)],
#  'ścisnąć': [('ręka', 4),
#   ('gardło', 2),
#   ('serce', 1),
#   ('tibi', 1),
#   ('krzyż', 1)],
#  'podle': [('chcieć', 1)],
#  'wykrzykiwać': [('wskazywać', 1),
#   ('sala', 1),
#   ('nagle', 1),
#   ('misiewiczowa', 1)],
#  'wstępny': [('ostatni', 1)],
#  'odeszlemy': [('zapytać', 1)],
#  'indie': [('mieszek', 1), ('china', 1), ('myśleć', 1), ('swój', 1)],
#  'akademia': [('szkoła', 1), ('śmiać', 1), ('geista', 1), ('francuski', 1)],
#  'przywieźć': [('siebie', 2),
#   ('zgadywać', 1),
#   ('turecki', 1),
#   ('opowiadać', 1),
#   ('kwit', 1)],
#  'danie': [('chcieć', 1)],
#  'brzydki': [('czas', 1),
#   ('pozostały', 1),
#   ('łapa', 1),
#   ('słowo', 1),
#   ('wołać', 1)],
#  'załatwić': [('interes', 2),
#   ('pilny', 2),
#   ('wierny', 1),
#   ('usługa', 1),
#   ('chwała', 1)],
#  'drwina': [('swój', 1), ('akademia', 1)],
#  'pukać': [('drzwi', 2),
#   ('okno', 2),
#   ('swój', 1),
#   ('wszystek', 1),
#   ('zbliżyć', 1)],
#  'statua': [('piramida', 1)],
#  'ucharakteryzować': [('dziesięć', 1),
#   ('serce', 1),
#   ('tęgi', 1),
#   ('trupa', 1)],
#  'rozpanoszyć': [('szlangbaum', 1), ('chwila', 1)],
#  'czyliż': [('prawo', 1),
#   ('słabieć', 1),
#   ('maić', 1),
#   ('piekło', 1),
#   ('chwila', 1)],
#  'lichwiarzyć': [('biedny', 1)],
#  'orać': [('ziemia', 1), ('ugór', 1)],
#  'rekomendować': [('podsuwać', 1),
#   ('myśleć', 1),
#   ('wziąć', 1),
#   ('mówić', 1),
#   ('swój', 1)],
#  'przechodzący': [('uporczywie', 1), ('wszelki', 1)],
#  'zabójczy': [('płeć', 1)],
#  'przeleżeć': [('dwanaście', 1)],
#  'wenecki': [('gondolier', 1)],
#  'sfora': [('podróż', 1)],
#  'porządki': [('nawracać', 1), ('tymczasem', 1)],
#  'masło': [('wisieć', 1), ('możny', 1)],
#  'technologiczny': [('niechże', 1), ('wyrosnąć', 1)],
#  'obserwatorium': [('rzucić', 1), ('baron', 1)],
#  'pożreć': [('skrzywić', 1)],
#  'wrzasnąć': [('baron', 2),
#   ('młody', 2),
#   ('stary', 1),
#   ('ogromny', 1),
#   ('ignacy', 1)],
#  'wypaść': [('ręka', 1),
#   ('niby', 1),
#   ('wokulski', 1),
#   ('pomyśleć', 1),
#   ('zaraz', 1)],
#  'kiełkować': [('uważać', 1), ('rozmaity', 1)],
#  'dopijać': [('czekolada', 1)],
#  'drapa': [('tedy', 1)],
#  'liczyć': [('kuchnia', 1),
#   ('swój', 1),
#   ('kilkanaście', 1),
#   ('myślić', 1),
#   ('wypadać', 1)],
#  'postęp': [('patrzyć', 1), ('wówczas', 1), ('społeczny', 1), ('umieć', 1)],
#  'jedynastej': [('panna', 1),
#   ('okno', 1),
#   ('wokulski', 1),
#   ('przedpokój', 1),
#   ('gabinet', 1)],
#  'szept': [('przysyłać', 1), ('modlitwa', 1), ('baron', 1), ('uścisk', 1)],
#  'nankinowy': [('spodnie', 3), ('zupełnie', 1)],
#  'brać': [('ręka', 4),
#   ('książka', 3),
#   ('wokulski', 2),
#   ('pieniądz', 2),
#   ('niewola', 2)],
#  'trzaskać': [('minuta', 1), ('bat', 1), ('głos', 1)],
#  'student': [('machać', 1),
#   ('wytworzyć', 1),
#   ('podobno', 1),
#   ('spełznąć', 1),
#   ('mieszkać', 1)],
#  'niebezpieczny': [('przemóc', 1), ('rozbić', 1), ('odeprzeć', 1)],
#  'karafka': [('podać', 2),
#   ('koniak', 2),
#   ('zimny', 1),
#   ('naznaczyć', 1),
#   ('wówczas', 1)],
#  'herbata': [('wciąż', 2),
#   ('przekonać', 1),
#   ('cytryna', 1),
#   ('odezwać', 1),
#   ('trzeć', 1)],
#  'kołatać': [('ojciec', 1), ('odezwać', 1)],
#  'stolarzyć': [('furman', 1)],
#  'wprawny': [('troszka', 1)],
#  'fajsławice': [('chory', 1)],
#  'wysypać': [('kuchnia', 1), ('chociaż', 1)],
#  'feston': [('biały', 1)],
#  'koł': [('podróżny', 1)],
#  'niechcący': [('lusterko', 1), ('potrącić', 1)],
#  'siedzenie': [('reszta', 1), ('prędko', 1), ('wyglądać', 1), ('fotel', 1)],
#  'cudze': [('wrócić', 1),
#   ('projekt', 1),
#   ('czekać', 1),
#   ('opinia', 1),
#   ('dawno', 1)],
#  'minclów': [('nienawidzić', 1),
#   ('anielski', 1),
#   ('zdobycie', 1),
#   ('musieć', 1),
#   ('wiedzieć', 1)],
#  'oboczny': [('czas', 1), ('pokój', 1)],
#  'helcia': [('przyjść', 1), ('dwadzieścia', 1)],
#  'związać': [('szlachta', 1),
#   ('zaczekać', 1),
#   ('związać', 1),
#   ('wierzyć', 1),
#   ('los', 1)],
#  'usiedzieć': [('pogodzić', 1)],
#  'triumfujący': [('złość', 1)],
#  'inszy': [('wszelki', 1), ('spodziewać', 1)],
#  'szczegółowo': [('historia', 1)],
#  'szmaragd': [('złoty', 1)],
#  'łącznik': [('chwila', 1), ('istnieć', 1)],
#  'przekąs': [('list', 1), ('dorobkiewicz', 1)],
#  'zarazić': [('swój', 2)],
#  'złodziej': [('niby', 1),
#   ('dalibóg', 1),
#   ('mniej', 1),
#   ('odeprzeć', 1),
#   ('pomyśleć', 1)],
#  'rezler': [('przypominać', 1)],
#  'letkiewicz': [('gałgan', 1), ('ciężki', 1)],
#  'podarunek': [('poczciwy', 1)],
#  'osiedle': [('młody', 1), ('kieliszek', 1)],
#  'czystość': [('wielki', 1), ('otaczać', 1)],
#  'burboni': [('trzy', 1)],
#  'przystawać': [('widocznie', 1)],
#  'hycel': [('august', 1), ('pała', 1)],
#  'ofiarować': [('tysiąc', 2),
#   ('lisiecki', 1),
#   ('para', 1),
#   ('swoić', 1),
#   ('pamiątkowy', 1)],
#  'soból': [('parasolka', 1)],
#  'przebierać': [('palec', 3),
#   ('instynkt', 1),
#   ('ojciec', 1),
#   ('widocznie', 1),
#   ('pójść', 1)],
#  'przemrugiwać': [('lada', 1)],
#  'założenie': [('braknąć', 1)],
#  'ojcowski': [('wizytować', 1), ('następnie', 1)],
#  'ociężały': [('znaleźć', 1)],
#  'zastanowienie': [('przyjechać', 1)],
#  'świetny': [('żywy', 1),
#   ('koń', 1),
#   ('pracować', 1),
#   ('prezent', 1),
#   ('dzieło', 1)],
#  'posyłać': [('dwieście', 1),
#   ('cztery', 1),
#   ('wystrzelić', 1),
#   ('trumna', 1),
#   ('tedy', 1)],
#  'dzień': [('noc', 3),
#   ('pojechać', 3),
#   ('siedzieć', 2),
#   ('miesiąc', 2),
#   ('stach', 2)],
#  'przeć': [('mieć', 2),
#   ('chyba', 2),
#   ('pięćdziesiąt', 2),
#   ('grossmutter', 2),
#   ('wobec', 2)],
#  'widocznie': [('pragnąć', 2),
#   ('popełnić', 1),
#   ('rzucić', 1),
#   ('kokietować', 1),
#   ('rozmyślać', 1)],
#  'napełniać': [('dusza', 1),
#   ('wielki', 1),
#   ('zresztą', 1),
#   ('potężny', 1),
#   ('podwyższać', 1)],
#  'diablica': [('krzeszowski', 1)],
#  'strzelić': [('palec', 2),
#   ('cesarz', 1),
#   ('błazen', 1),
#   ('latać', 1),
#   ('głowa', 1)],
#  'quichot': [('rysunki', 1), ('szczęśliwy', 1)],
#  'prezentować': [('powaga', 1),
#   ('brązowy', 1),
#   ('następnie', 1),
#   ('obcesowo', 1),
#   ('rzec', 1)],
#  'powstały': [('klęczki', 1), ('naprzeciw', 1)],
#  'upłynąć': [('dziesięć', 3),
#   ('osiem', 1),
#   ('nagle', 1),
#   ('wielki', 1),
#   ('trzeci', 1)],
#  'powściągliwy': [('niekiedy', 1)],
#  'amerykański': [('milioner', 1), ('móc', 1)],
#  'filować': [('zacząć', 1)],
#  'przysłonić': [('chmura', 1), ('obłok', 1), ('tafla', 1), ('niebieski', 1)],
#  'powołać': [('głupstwo', 1), ('świat', 1), ('świadectwo', 1)],
#  'pręt': [('stąd', 1), ('druga', 1)],
#  'temperatura': [('paryż', 1), ('dochód', 1)],
#  'cioteczka': [('kokietować', 1)],
#  'odzywać': [('schrypnięty', 1),
#   ('dać', 1),
#   ('ojciec', 1),
#   ('zaszczycić', 1),
#   ('wystraszyć', 1)],
#  'obca': [('mowa', 1), ('raczyć', 1), ('zacząć', 1)],
#  'upajać': [('zły', 1)],
#  'tajemniczość': [('znać', 1)],
#  'żałośnie': [('trząść', 1), ('próżno', 1)],
#  'prezesowa': [('ręka', 1),
#   ('dawny', 1),
#   ('historia', 1),
#   ('staruszka', 1),
#   ('naradzać', 1)],
#  'przerywać': [('panna', 1),
#   ('minąć', 1),
#   ('adwokat', 1),
#   ('łęcki', 1),
#   ('wysoce', 1)],
#  'oświetlić': [('okno', 3),
#   ('błysnąć', 1),
#   ('olejna', 1),
#   ('część', 1),
#   ('oboj', 1)],
#  'przysiąść': [('staruszka', 1)],
#  'złocić': [('malować', 1),
#   ('wysokość', 1),
#   ('unosić', 1),
#   ('figura', 1),
#   ('olbrzym', 1)],
#  'dwugarbny': [('dodać', 1)],
#  'obmierzić': [('adamowy', 1)],
#  'nawyknąć': [('dodać', 1), ('przysionek', 1)],
#  'znajdować': [('przeddzień', 2),
#   ('środek', 2),
#   ('zupa', 1),
#   ('dama', 1),
#   ('trafiać', 1)],
#  'ordynaryjny': [('pokłócić', 1)],
#  'goń': [('chociaż', 1)],
#  'znaczny': [('marszałek', 1)],
#  'wałkoń': [('cztery', 1)],
#  'niesforny': [('rzec', 1), ('odzywać', 1)],
#  'przebiegać': [('myśl', 2),
#   ('wzór', 1),
#   ('aksamitny', 1),
#   ('oblicze', 1),
#   ('płochliwy', 1)],
#  'żardynierka': [('wazon', 1)],
#  'lusterko': [('stolik', 1)],
#  'zadłużać': [('swój', 1)],
#  'murować': [('zapomnieć', 1), ('budynek', 1)],
#  'pneumatyczny': [('osmagać', 1)],
#  'niezadowolony': [('pobyt', 1), ('widzieć', 1)],
#  'wąski': [('kanapka', 1),
#   ('pantofelek', 1),
#   ('stanowić', 1),
#   ('sierp', 1),
#   ('sztylecik', 1)],
#  'odmalować': [('myć', 1), ('uczuć', 1)],
#  'pocić': [('swój', 1), ('druga', 1)],
#  'hydrauliczny': [('stworzyć', 1)],
#  'nieśmiertelny': [('zstąpić', 1), ('mucha', 1), ('równy', 1)],
#  'ciemnieć': [('gęsto', 1)],
#  'wyrabiać': [('soba', 1),
#   ('zakładać', 1),
#   ('mieć', 1),
#   ('nachodzić', 1),
#   ('człowiek', 1)],
#  'nerwy': [('bulwar', 2), ('baron', 1)],
#  'popłatny': [('kilkadziesiąt', 1)],
#  'papillons': [('vois', 1)],
#  'kłąb': [('dym', 1), ('daleki', 1), ('rozeprzeć', 1), ('żółty', 1)],
#  'fundament': [('szepnąć', 1), ('dobrobyt', 1)],
#  'doradca': [('powrót', 1), ('zapraszać', 1), ('prawny', 1), ('por', 1)],
#  'warunki': [('móc', 2),
#   ('zapoznać', 1),
#   ('niezwykły', 1),
#   ('bezwstydny', 1),
#   ('święty', 1)],
#  'muzyka': [('złożony', 2),
#   ('szkatułka', 1),
#   ('tańczyć', 1),
#   ('szósty', 1),
#   ('wchodzić', 1)],
#  'cofny': [('spółka', 1), ('mówić', 1)],
#  'wyobrażać': [('soba', 8),
#   ('dopiero', 1),
#   ('arystokracja', 1),
#   ('maić', 1),
#   ('przyjemny', 1)],
#  'marszczyć': [('brew', 2),
#   ('rozum', 1),
#   ('sprawiedliwość', 1),
#   ('siadać', 1),
#   ('potrącić', 1)],
#  'uniewinniać': [('zakończyć', 1)],
#  'uczuć': [('brak', 2),
#   ('panna', 2),
#   ('ściskanie', 2),
#   ('plecy', 1),
#   ('wewnętrzny', 1)],
#  'nalewka': [('szlangbaum', 1)],
#  'biurko': [('leżeć', 2),
#   ('nożyk', 1),
#   ('potem', 1),
#   ('napisać', 1),
#   ('rzec', 1)],
#  'hebanowy': [('laseczka', 1)],
#  'odsuwać': [('tamburek', 1), ('siebie', 1), ('warszawa', 1), ('chcieć', 1)],
#  'wdrapać': [('zobaczyć', 1), ('pierwszy', 1)],
#  'narodzić': [('kupić', 1)],
#  'łaskawie': [('człowiek', 1), ('zabrać', 1)],
#  'miętosić': [('czapka', 1)],
#  'uroczyście': [('otwierać', 1),
#   ('minclowie', 1),
#   ('potrzebować', 1),
#   ('ażeby', 1),
#   ('podnieść', 1)],
#  'oszczędności': [('stała', 1), ('najmniej', 1), ('naród', 1)],
#  'helenka': [('oczywiście', 1),
#   ('pracować', 1),
#   ('niepoczciwy', 1),
#   ('rzec', 1),
#   ('posada', 1)],
#  'pobudka': [('serce', 1)],
#  'kula': [('nieprzyjacielski', 1),
#   ('sprzedać', 1),
#   ('przelecieć', 1),
#   ('zamek', 1),
#   ('panna', 1)],
#  'akszamitny': [('przyszyć', 1)],
#  'nuty': [('czwarty', 1)],
#  'utknąć': [('lampa', 1)],
#  'wytarzać': [('kuchenny', 1)],
#  'fronton': [('płaskorzeźba', 1)],
#  'nastawić': [('zamek', 1)],
#  'nóż': [('tysiąc', 1),
#   ('wbić', 1),
#   ('panna', 1),
#   ('pomyśleć', 1),
#   ('doprawdy', 1)],
#  'lubić': [('lubić', 2),
#   ('szampan', 2),
#   ('mówić', 2),
#   ('rzec', 2),
#   ('wtóry', 2)],
#  'haremowy': [('traktować', 1)],
#  'leon': [('mówić', 1),
#   ('zaiskrzyć', 1),
#   ('począć', 1),
#   ('dostać', 1),
#   ('wyrzucać', 1)],
#  'zuchwały': [('rok', 1),
#   ('zapieczętować', 1),
#   ('widzieć', 1),
#   ('myśleć', 1),
#   ('czyn', 1)],
#  'nieprzeparty': [('chęć', 1), ('śmierć', 1)],
#  'wytłomaczyć': [('instynkt', 1),
#   ('kamienica', 1),
#   ('zasada', 1),
#   ('towar', 1),
#   ('soba', 1)],
#  'stójkowy': [('prawo', 1), ('przeżegnać', 1), ('komornik', 1)],
#  'nazwać': [('zwymyślać', 1),
#   ('miłość', 1),
#   ('łęcki', 1),
#   ('rok', 1),
#   ('domiar', 1)],
#  'uczłowieczyć': [('miłość', 1)],
#  'poprowadzić': [('zostać', 1)],
#  'potrzeba': [('bielizna', 2),
#   ('robić', 2),
#   ('wymian', 1),
#   ('łączyć', 1),
#   ('odrodzenie', 1)],
#  'rozwijać': [('zaczynać', 1),
#   ('papier', 1),
#   ('przybierać', 1),
#   ('bestia', 1),
#   ('wprost', 1)],
#  'wydzysz': [('pyniądze', 1)],
#  'znawca': [('pierwszy', 1), ('egipski', 1), ('męski', 1), ('myśleć', 1)],
#  'pragnienie': [('życie', 1),
#   ('tęskny', 1),
#   ('wierzyć', 1),
#   ('wynaleźć', 1),
#   ('resztka', 1)],
#  'dłużnik': [('zwrócić', 1)],
#  'oparcie': [('zawrzeć', 1)],
#  'wznosić': [('piętrowy', 2),
#   ('dół', 1),
#   ('pagórek', 1),
#   ('góry', 1),
#   ('siebie', 1)],
#  'piekielny': [('robić', 1), ('przybyły', 1), ('szanować', 1)],
#  'przemówić': [('siebie', 1), ('zaszumiać', 1), ('chcieć', 1), ('para', 1)],
#  'jędza': [('odpokutować', 1), ('wyczerpać', 1), ('lalka', 1)],
#  'wydział': [('ruski', 1), ('przyrodniczy', 1), ('widny', 1)],
#  'spękać': [('skorupa', 1), ('ściana', 1)],
#  'utwierdzić': [('dobry', 1), ('zacny', 1)],
#  'obelisk': [('ogarnąć', 1), ('luxor', 1)],
#  'żebrak': [('błagać', 1), ('człowiek', 1), ('odsłonić', 1)],
#  'przywiązywać': [('rzucać', 1), ('klejna', 1)],
#  'rossiego': [('warszawa', 1),
#   ('świat', 1),
#   ('wyjazd', 1),
#   ('widzieć', 1),
#   ('mówić', 1)],
#  'dywan': [('posąg', 1),
#   ('głuszyć', 1),
#   ('ubranie', 1),
#   ('szal', 1),
#   ('chwila', 1)],
#  'przeprosić': [('panna', 4),
#   ('listownie', 1),
#   ('drogi', 1),
#   ('zakończyć', 1),
#   ('zakląć', 1)],
#  'słuch': [('mówić', 1), ('chwytać', 1)],
#  'oddać': [('list', 4),
#   ('ręka', 2),
#   ('swoić', 2),
#   ('serwis', 2),
#   ('sklep', 2)],
#  'zdejmować': [('kapelusz', 2),
#   ('kładnąć', 1),
#   ('dyscyplina', 1),
#   ('myśleć', 1),
#   ('kręcić', 1)],
#  'lękać': [('ażeby', 4),
#   ('zastąpić', 1),
#   ('wstydzić', 1),
#   ('chwycić', 1),
#   ('powiedzieć', 1)],
#  'mdły': [('mucha', 1)],
#  'rozstrzygać': [('los', 1)],
#  'wpadać': [('sklep', 2),
#   ('otwarty', 2),
#   ('pokój', 2),
#   ('pieprz', 1),
#   ('gabinet', 1)],
#  'zaciągać': [('dług', 4),
#   ('ojciec', 1),
#   ('jakikolwiek', 1),
#   ('alboż', 1),
#   ('wielmożny', 1)],
#  'wryć': [('stanąć', 1)],
#  'wspólność': [('trocha', 1), ('zaraz', 1)],
#  'odkłonić': [('upadły', 1)],
#  'kiełbasa': [('cukiernia', 1), ('aniżeli', 1), ('powiedzieć', 1)],
#  'znakomity': [('adwokat', 3),
#   ('panna', 2),
#   ('żyd', 1),
#   ('reporter', 1),
#   ('przyjaciel', 1)],
#  'spłatać': [('córka', 1)],
#  'vilagos': [('opaść', 1)],
#  'zoologia': [('specjalnie', 1)],
#  'wzdłużyć': [('ściana', 2),
#   ('gościniec', 1),
#   ('galicja', 1),
#   ('aleja', 1),
#   ('przypatrywać', 1)],
#  'powab': [('chory', 1)],
#  'trwonić': [('majątek', 1),
#   ('zrobić', 1),
#   ('żona', 1),
#   ('trwonić', 1),
#   ('ojciec', 1)],
#  'pokaźny': [('zarazem', 1)],
#  'przytaczać': [('nazwisko', 1), ('dowód', 1)],
#  'zdarzyć': [('widzieć', 2),
#   ('ważny', 1),
#   ('stajnia', 1),
#   ('znać', 1),
#   ('równia', 1)],
#  'konar': [('pokazać', 1)],
#  'triumfalnie': [('spoglądać', 1), ('szuman', 1)],
#  'zaryć': [('zaczynać', 1), ('ziemia', 1)],
#  'wolny': [('podnieść', 3),
#   ('zasobny', 1),
#   ('dziwić', 1),
#   ('godzina', 1),
#   ('posuwać', 1)],
#  'przykryć': [('zielony', 1)],
#  'wykonanie': [('chcieć', 1), ('ogromnie', 1), ('brak', 1), ('brakować', 1)],
#  'naginać': [('trafić', 1)],
#  'kochanek': [('myśleć', 1), ('prędko', 1)],
#  'fenomenalny': [('lubić', 1)],
#  'dzwonek': [('odbyć', 1),
#   ('przedpokój', 1),
#   ('trzask', 1),
#   ('wówczas', 1),
#   ('potem', 1)],
#  'niespodziewany': [('wizyta', 1), ('wyjazd', 1)],
#  'płacić': [('dobry', 3),
#   ('siedemset', 3),
#   ('rubel', 2),
#   ('wszystek', 2),
#   ('tyli', 2)],
#  'stworzyć': [('ażeby', 2),
#   ('towarzystwo', 1),
#   ('nowy', 1),
#   ('móc', 1),
#   ('kobieta', 1)],
#  'sklepowy': [('czuć', 1),
#   ('polityk', 1),
#   ('wystawa', 1),
#   ('chwila', 1),
#   ('zostać', 1)],
#  'krajowy': [('drugi', 1), ('mieć', 1), ('sprowadzać', 1), ('ażeby', 1)],
#  'nagi': [('drzewo', 1)],
#  'stanąć': [('drzwi', 5),
#   ('próg', 3),
#   ('chodnik', 2),
#   ('tomasz', 2),
#   ('oko', 2)],
#  'zebranie': [('mruknąć', 1)],
#  'zdanie': [('ojciec', 2),
#   ('wypowiadać', 1),
#   ('kwestia', 1),
#   ('mieć', 1),
#   ('stasio', 1)],
#  'antrakt': [('mieć', 1)],
#  'zapakować': [('wszystek', 1), ('swój', 1)],
#  'zwierzyć': [('cienki', 1),
#   ('stać', 1),
#   ('spokoić', 1),
#   ('bawić', 1),
#   ('stawska', 1)],
#  'wehikuł': [('przestrzeń', 1)],
#  'waliza': [('stacha', 1), ('wirski', 1)],
#  'kilkudniowy': [('podróż', 1)],
#  'roztropny': [('wyłączać', 1)],
#  'piorun': [('móc', 1),
#   ('oddać', 1),
#   ('przywlec', 1),
#   ('burza', 1),
#   ('rana', 1)],
#  'kaskada': [('tkanina', 1)],
#  'drwa': [('dzienić', 1)],
#  'zażyć': [('wokulski', 1)],
#  'poczynać': [('przypatrywać', 1),
#   ('kręcić', 1),
#   ('tęsknić', 1),
#   ('soba', 1),
#   ('jakoż', 1)],
#  'braknąć': [('fantastyczny', 1),
#   ('miejsce', 1),
#   ('zawołać', 1),
#   ('siostra', 1),
#   ('kobieta', 1)],
#  'uzda': [('zaprowadzić', 1)],
#  'domyślić': [('czuć', 1), ('narobić', 1), ('panna', 1)],
#  'trocadero': [('pilnie', 1), ('prawo', 1)],
#  'odprawić': [('ofiarować', 1),
#   ('służący', 1),
#   ('przybiec', 1),
#   ('interesant', 1)],
#  'koronka': [('dziesięć', 1), ('skutek', 1), ('baronowy', 1)],
#  'przypomnienie': [('soba', 1)],
#  'popędzić': [('jezdny', 1), ('lokaj', 1)],
#  'zarówno': [('obcy', 1), ('mieszkać', 1)],
#  'nieboszczka': [('prezesowy', 3),
#   ('służyć', 1),
#   ('trzymać', 1),
#   ('grossmutter', 1),
#   ('ostatni', 1)],
#  'mumia': [('skończyć', 1)],
#  'zaginąć': [('drobny', 1)],
#  'pięćdziesięcioletni': [('dopiero', 1), ('skłonny', 1)],
#  'zdziwaczeć': [('chłop', 1)],
#  'synonim': [('rzucić', 1)],
#  'nagadać': [('musieć', 1), ('stary', 1), ('rozumieć', 1)],
#  'resurs': [('chcieć', 1), ('pomiatać', 1), ('dzienić', 1)],
#  'dosięgły': [('najwyższy', 1), ('pięć', 1)],
#  'obraza': [('ująć', 1), ('siebie', 1)],
#  'utworzyć': [('wielki', 1),
#   ('las', 1),
#   ('nowa', 1),
#   ('biały', 1),
#   ('formalny', 1)],
#  'zaatakować': [('nóż', 1)],
#  'wstawać': [('rano', 1),
#   ('stół', 1),
#   ('kłaść', 1),
#   ('hrabia', 1),
#   ('woli', 1)],
#  'pewno': [('wyleczyć', 1),
#   ('czekać', 1),
#   ('spodziewać', 1),
#   ('piętnaście', 1),
#   ('powtarzać', 1)],
#  'poprzek': [('drogi', 1)],
#  'towar': [('kolonialny', 2),
#   ('kupiec', 1),
#   ('gablotka', 1),
#   ('tutka', 1),
#   ('zjawiać', 1)],
#  'próżniaczy': [('wynajdywać', 1), ('próżnować', 1)],
#  'rzec': [('wokulski', 27),
#   ('panna', 21),
#   ('siebie', 7),
#   ('ochocki', 7),
#   ('chwila', 6)],
#  'trwać': [('wieczor', 1),
#   ('triumf', 1),
#   ('polegać', 1),
#   ('program', 1),
#   ('wakacje', 1)],
#  'śniadanie': [('pożegnać', 1),
#   ('potem', 1),
#   ('swój', 1),
#   ('wyjść', 1),
#   ('zdawać', 1)],
#  'oburzony': [('chcieć', 1), ('przypomnieć', 1)],
#  'krótki': [('czas', 2),
#   ('tyli', 2),
#   ('alboż', 1),
#   ('czytać', 1),
#   ('średnica', 1)],
#  'oskubać': [('potem', 1)],
#  'zatrwożyć': [('panna', 1),
#   ('staruszka', 1),
#   ('mówić', 1),
#   ('przypomnieć', 1)],
#  'wściekłość': [('martwy', 1), ('chwila', 1)],
#  'starzec': [('rumiany', 1),
#   ('odbierać', 1),
#   ('potrząsnąć', 1),
#   ('prześladować', 1),
#   ('piaskowy', 1)],
#  'polecić': [('tomasz', 1)],
#  'przełknąć': [('twarz', 1)],
#  'wleźć': [('obrzydliwy', 1),
#   ('bośnia', 1),
#   ('panna', 1),
#   ('choćby', 1),
#   ('iść', 1)],
#  'walc': [('dźwięk', 1),
#   ('dziki', 1),
#   ('potem', 1),
#   ('silny', 1),
#   ('zwyciężać', 1)],
#  'pompować': [('woda', 1), ('koniec', 1)],
#  'zręcznie': [('palmieri', 1)],
#  'przyszły': [('zawołać', 1),
#   ('właściciel', 1),
#   ('pokolenie', 1),
#   ('wokulski', 1),
#   ('pański', 1)],
#  'deszczowy': [('znajomy', 1)],
#  'męka': [('trzasnąć', 1), ('koń', 1)],
#  'błogosławić': [('grywać', 1),
#   ('podejść', 1),
#   ('doznać', 1),
#   ('wodny', 1),
#   ('głośno', 1)],
#  'bezczelnie': [('głupi', 1), ('pożałować', 1)],
#  'powiadać': [('nareszcie', 1),
#   ('zacząć', 1),
#   ('stanisław', 1),
#   ('zobaczyć', 1),
#   ('czyjś', 1)],
#  'budowniczy': [('wokulski', 1)],
#  'dziesiętny': [('wyobrazić', 1)],
#  'porównanie': [('kupia', 1), ('bieg', 1), ('mieszkaniec', 1), ('aniżeli', 1)],
#  'wyrywać': [('wina', 1),
#   ('rozumny', 1),
#   ('znikać', 1),
#   ('chloroform', 1),
#   ('zedrzeć', 1)],
#  'przysłuchiwać': [('łoskot', 1),
#   ('własny', 1),
#   ('dzienić', 1),
#   ('panna', 1),
#   ('gorączkowy', 1)],
#  'południe': [('wokulski', 2),
#   ('zmniejszać', 1),
#   ('kazać', 1),
#   ('składać', 1),
#   ('ukazać', 1)],
#  'wieś': [('spotykać', 1),
#   ('nazwa', 1),
#   ('spoza', 1),
#   ('rana', 1),
#   ('starać', 1)],
#  'licytować': [('razem', 1),
#   ('znać', 1),
#   ('baronowy', 1),
#   ('znajda', 1),
#   ('szeroko', 1)],
#  'szeroki': [('ulica', 2),
#   ('myśleć', 1),
#   ('ogarnąć', 1),
#   ('parów', 1),
#   ('kilkaset', 1)],
#  'szpara': [('firanka', 1), ('bok', 1)],
#  'wygoić': [('jęczeć', 1)],
#  'ukochana': [('baronowy', 1), ('liczba', 1)],
#  'potężnieć': [('nareszcie', 1)],
#  'uczęszczać': [('przyzwoity', 1)],
#  'sprytny': [('trocha', 2),
#   ('wyjść', 1),
#   ('mistrzowski', 1),
#   ('grunt', 1),
#   ('ojciec', 1)],
#  'skierowywać': [('ósmy', 1)],
#  'śmiech': [('panna', 3),
#   ('wokulski', 2),
#   ('wejść', 2),
#   ('strącić', 1),
#   ('przysłuchiwać', 1)],
#  'bezwstydny': [('dorożkarz', 1), ('żebrak', 1)],
#  'upływ': [('rok', 1),
#   ('trzy', 1),
#   ('godzina', 1),
#   ('nieudolny', 1),
#   ('żyd', 1)],
#  'wojenny': [('pisanina', 1)],
#  'pchnąć': [('twardy', 1), ('depesza', 1), ('komornik', 1)],
#  'bonapartych': [('trząść', 1),
#   ('pierwszy', 1),
#   ('sprawiedliwość', 1),
#   ('tymczasem', 1)],
#  'serduszko': [('móc', 1)],
#  'przenośny': [('popas', 1)],
#  'przekupić': [('adwokat', 1)],
#  'bałamut': [('mąż', 1), ('samiec', 1)],
#  'naczelny': [('miejsce', 1)],
#  'gniew': [('panna', 2),
#   ('zerwać', 1),
#   ('ręka', 1),
#   ('pierwszy', 1),
#   ('forma', 1)],
#  'nierozważny': [('dopiero', 1)],
#  'trupi': [('główka', 2),
#   ('czego', 1),
#   ('głowa', 1),
#   ('pukać', 1),
#   ('konferencja', 1)],
#  'łucja': [('lamermooru', 1)],
#  'ubiór': [('wiosenny', 1), ('wpadać', 1)],
#  'atakować': [('roznosiciel', 1)],
#  'szczenię': [('późno', 1)],
#  'przypochlebić': [('wymyślać', 1)],
#  'widzieć': [('siebie', 8),
#   ('panna', 5),
#   ('rzec', 5),
#   ('wokulski', 4),
#   ('zacząć', 4)],
#  'wzrosnąć': [('operacja', 1), ('wzrastać', 1)],
#  'domański': [('trocha', 1),
#   ('upadać', 1),
#   ('wraz', 1),
#   ('chcieć', 1),
#   ('półtora', 1)],
#  'przykry': [('dotknąć', 2),
#   ('rzec', 1),
#   ('staś', 1),
#   ('chwila', 1),
#   ('niespodzianka', 1)],
#  'musieć': [('zrobić', 4),
#   ('miecić', 4),
#   ('pójść', 4),
#   ('pierwej', 4),
#   ('szukać', 3)],
#  'przelotnia': [('panna', 1), ('spojrzeć', 1)],
#  'zuzanna': [('zebrać', 1)],
#  'zbłąkany': [('kula', 1)],
#  'niezwykły': [('rano', 1),
#   ('fizjognomia', 1),
#   ('opanować', 1),
#   ('mieć', 1),
#   ('zdawać', 1)],
#  'zagraniczny': [('kapitalista', 1), ('kobieta', 1), ('przybłęda', 1)],
#  'nieśmiało': [('delikatnie', 1), ('tyli', 1), ('odpowiedzieć', 1)],
#  'przenieść': [('skierniewice', 2),
#   ('swoić', 1),
#   ('zajmować', 1),
#   ('zamiast', 1),
#   ('praga', 1)],
#  'światła': [('uliczny', 1),
#   ('daleki', 1),
#   ('łabędzi', 1),
#   ('ignacy', 1),
#   ('spotkać', 1)],
#  'szczotka': [('zacząć', 1), ('możny', 1)],
#  'półgodzina': [('przychodzić', 1)],
#  'popłacić': [('byle', 1)],
#  'popłoch': [('bawełniany', 1)],
#  'melioracja': [('należeć', 1)],
#  'rezerwa': [('świni', 1), ('licytować', 1), ('wokulski', 1)],
#  'biesiadnik': [('zabierać', 1)],
#  'chmura': [('nazajutrz', 1),
#   ('ażeby', 1),
#   ('mieszać', 1),
#   ('rozedrzeć', 1),
#   ('zgęszczać', 1)],
#  'przyciszyć': [('pierwszy', 1),
#   ('jeździć', 1),
#   ('dlaczegóż', 1),
#   ('pewnie', 1),
#   ('jaśnie', 1)],
#  'jedyna': [('córka', 2),
#   ('wynieść', 2),
#   ('rzecz', 1),
#   ('siła', 1),
#   ('zawodzić', 1)],
#  'nawiasowo': [('serdecznie', 1)],
#  'relacja': [('wprost', 1)],
#  'niemniej': [('gorąco', 1),
#   ('otrzeć', 1),
#   ('móc', 1),
#   ('interesować', 1),
#   ('zrobić', 1)],
#  'niedbały': [('powitać', 1), ('ażeby', 1)],
#  'koleżeński': [('dopiero', 1), ('oświadczać', 1)],
#  'niekorzystny': [('donieść', 1)],
#  'ekscentryczność': [('smutek', 1), ('baron', 1)],
#  'bezwarunkowo': [('ażeby', 1)],
#  'uwziąć': [('metternichowski', 1)],
#  'pomieszać': [('późno', 1), ('rachunki', 1)],
#  'starannie': [('czuwać', 1),
#   ('pistolet', 1),
#   ('zasłonić', 1),
#   ('stopa', 1),
#   ('widocznie', 1)],
#  'zdjąć': [('wokulski', 2),
#   ('kamasz', 2),
#   ('wielki', 1),
#   ('straszny', 1),
#   ('czapka', 1)],
#  'rozcinać': [('musieć', 1)],
#  'wyśmiewać': [('własne', 1), ('złudzenie', 1), ('nigdyś', 1)],
#  'trzeźwo': [('patrzeć', 2)],
#  'pszczoła': [('spostrzec', 1), ('budujący', 1), ('lepić', 1)],
#  'wybaczyć': [('wzgląd', 1),
#   ('prezentować', 1),
#   ('siebie', 1),
#   ('angielski', 1),
#   ('zawołać', 1)],
#  'chat': [('wiatr', 1), ('ogląduję', 1), ('kryty', 1)],
#  'serio': [('zapytać', 1),
#   ('począć', 1),
#   ('myśl', 1),
#   ('brać', 1),
#   ('wziąć', 1)],
#  'pień': [('czerwony', 1),
#   ('unikać', 1),
#   ('mówić', 1),
#   ('ściąć', 1),
#   ('rzadko', 1)],
#  'modły': [('zostać', 1)],
#  'argumenta': [('panna', 1)],
#  'zachwycać': [('przejść', 1),
#   ('spółka', 1),
#   ('pędzić', 1),
#   ('kokietować', 1),
#   ('przynosić', 1)],
#  'lada': [('dzienić', 5),
#   ('chwila', 3),
#   ('okoliczność', 1),
#   ('prosić', 1),
#   ('lada', 1)],
#  'okienny': [('pojąć', 1), ('framuga', 1)],
#  'okrzyk': [('wreszcie', 1),
#   ('dzwonek', 1),
#   ('głośny', 1),
#   ('zatrzymać', 1),
#   ('otwierać', 1)],
#  'kokieteria': [('kobieta', 1), ('mężczyzna', 1), ('obojętny', 1), ('bel', 1)],
#  'wotywa': [('dusza', 1)],
#  'terytorium': [('należący', 1)],
#  'bonapartysta': [('myśleć', 1)],
#  'zostawić': [('swoić', 3),
#   ('soba', 2),
#   ('para', 2),
#   ('chwila', 2),
#   ('tyli', 2)],
#  'encyklopedia': [('wielki', 1)],
#  'komorny': [('przyjść', 1),
#   ('wynająć', 1),
#   ('dawny', 1),
#   ('rozum', 1),
#   ('pobierać', 1)],
#  'planet': [('mieszkać', 1)],
#  'czuć': [('potrzeba', 4),
#   ('soba', 4),
#   ('brak', 2),
#   ('zupełnie', 2),
#   ('mocnieć', 1)],
#  'strącić': [('rabat', 1), ('siebie', 1), ('pociąg', 1)],
#  'meine': [('kaffee', 3), ('dostawać', 1)],
#  'żołnierz': [('osiem', 1),
#   ('znaleźć', 1),
#   ('móc', 1),
#   ('deszcz', 1),
#   ('prawo', 1)],
#  'tęga': [('naród', 1)],
#  'poniekąd': [('honorowy', 1)],
#  'suchotniczy': [('mieć', 1)],
#  'zbiegły': [('górka', 1), ('przyjaciel', 1)],
#  'tyralier': [('pobiec', 1)],
#  'odsyłać': [('możny', 1),
#   ('chaos', 1),
#   ('wszystek', 1),
#   ('swoić', 1),
#   ('powrót', 1)],
#  'różny': [('gatunek', 2),
#   ('punkt', 2),
#   ('rzecz', 2),
#   ('świat', 1),
#   ('głos', 1)],
#  'zdziwiony': [('przypatrywać', 2),
#   ('panna', 1),
#   ('zerwać', 1),
#   ('wokulski', 1),
#   ('hrabia', 1)],
#  'zatrzasnąć': [('drzwi', 2),
#   ('drzwiczki', 1),
#   ('siebie', 1),
#   ('wrócić', 1),
#   ('żegnać', 1)],
#  'halucynacja': [('rzec', 1)],
#  'drogocenny': [('las', 1)],
#  'wrzesień': [('prezesowy', 1)],
#  'trysnąć': [('pysznie', 1), ('okno', 1)],
#  'zgoła': [('podły', 1), ('niekiedy', 1)],
#  'paszjami': [('lubić', 1)],
#  'wilgotny': [('prosto', 1)],
#  'ogrzać': [('ręka', 1)],
#  'ułomna': [('deptać', 1)],
#  'okular': [('fizjognomia', 1),
#   ('cofać', 1),
#   ('kłaniać', 1),
#   ('minąć', 1),
#   ('nieco', 1)],
#  'czterysta': [('rubel', 6),
#   ('baron', 1),
#   ('sfałszować', 1),
#   ('kilkadziesiąt', 1)],
#  'knajpa': [('prosty', 1)],
#  'dyrektorski': [('władza', 1)],
#  'kontraltowy': [('głos', 1)],
#  'przemknąć': [('mieć', 1), ('głębia', 1), ('głowa', 1)],
#  'stołek': [('potem', 1)],
#  'dławić': [('dusić', 1), ('szarpać', 1)],
#  'zręczność': [('podsadzić', 1)],
#  'wzniesienie': [('furman', 1)],
#  'restauracja': [('ulica', 1)],
#  'targować': [('żądać', 1),
#   ('tamto', 1),
#   ('wokulski', 1),
#   ('chcieć', 1),
#   ('ażeby', 1)],
#  'kora': [('mieszek', 1), ('połamać', 1), ('młody', 1)],
#  'czternaście': [('rok', 1)],
#  'ochłonąć': [('poczuć', 1),
#   ('mówić', 1),
#   ('pogrozić', 1),
#   ('nabrać', 1),
#   ('skoczyć', 1)],
#  'rumiany': [('otoczyć', 1),
#   ('twarz', 1),
#   ('towarzyszyć', 1),
#   ('pyszny', 1),
#   ('poczciwy', 1)],
#  'skupić': [('naszać', 1),
#   ('grzmot', 1),
#   ('przystępować', 1),
#   ('rzecki', 1),
#   ('móc', 1)],
#  'zerwać': [('krzesło', 4),
#   ('panna', 4),
#   ('towarzystwo', 2),
#   ('spytać', 2),
#   ('fotel', 2)],
#  'czyż': [('wypadać', 1),
#   ('słyszeć', 1),
#   ('stary', 1),
#   ('dowiedzieć', 1),
#   ('istnieć', 1)],
#  'przyszywać': [('guzik', 1), ('oberwany', 1)],
#  'pistolet': [('wędrować', 1),
#   ('szczelina', 1),
#   ('ognisty', 1),
#   ('gwintować', 1),
#   ('wstąpić', 1)],
#  'posępnie': [('zdradzać', 1), ('słuchać', 1), ('kryć', 1)],
#  'tyć': [('sądzić', 1),
#   ('stać', 1),
#   ('dzienić', 1),
#   ('zabraknąć', 1),
#   ('lampa', 1)],
#  'przyjeżdżać': [('beleć', 1),
#   ('pytać', 1),
#   ('zarobić', 1),
#   ('wełna', 1),
#   ('para', 1)],
#  'poważny': [('ojcowie', 1),
#   ('maić', 1),
#   ('zarysowywać', 1),
#   ('mnóstwo', 1),
#   ('osoba', 1)],
#  'fatalność': [('popychać', 1)],
#  'porównać': [('rok', 1),
#   ('położyć', 1),
#   ('dyskretny', 1),
#   ('delikatny', 1),
#   ('możny', 1)],
#  'pręgierz': [('biedny', 1)],
#  'kpina': [('zdrowy', 1)],
#  'ignaś': [('doczekać', 1), ('odpowiedzieć', 1)],
#  'dłoń': [('mruczeć', 1),
#   ('wykonywać', 1),
#   ('dług', 1),
#   ('móc', 1),
#   ('rozgorączkować', 1)],
#  'niezupełnie': [('dać', 1), ('wstyd', 1)],
#  'wściekać': [('stado', 1), ('mruknąć', 1), ('budzić', 1)],
#  'hopferowi': [('zwabiać', 1), ('zamieszkać', 1)],
#  'quichotem': [('zapragnąć', 1)],
#  'wyprawiać': [('urodziny', 1)],
#  'porządnie': [('prowadzić', 1), ('bić', 1), ('kupić', 1)],
#  'napić': [('napoleon', 1), ('uspokoić', 1), ('woda', 1)],
#  'metalowy': [('guzik', 2), ('siebie', 1), ('kulka', 1), ('kart', 1)],
#  'daszek': [('kaska', 1), ('słychać', 1)],
#  'skropić': [('niewidzialny', 1)],
#  'osady': [('rolny', 1)],
#  'migać': [('błysnąć', 1), ('drzewo', 1), ('cień', 1)],
#  'odziedziczyć': [('żona', 1),
#   ('interes', 1),
#   ('praktyka', 1),
#   ('fortuna', 1),
#   ('sklep', 1)],
#  'mniejsza': [('pokrycie', 1),
#   ('zatrzymać', 1),
#   ('projekt', 1),
#   ('tymczasem', 1),
#   ('dopiero', 1)],
#  'uwięziony': [('forma', 1), ('wiorsta', 1)],
#  'nieudolny': [('ciąg', 1)],
#  'dysponować': [('osoba', 1)],
#  'węgier': [('ogół', 1),
#   ('szwab', 1),
#   ('zmorzyć', 1),
#   ('liczyć', 1),
#   ('wojna', 1)],
#  'niecierpliwić': [('któż', 1)],
#  'stachowej': [('zamiast', 1)],
#  'suszyć': [('dziecinny', 1)],
#  'obsiadać': [('pleśń', 1)],
#  'gondolier': [('cyrkowy', 1)],
#  'oblać': [('zimne', 3),
#   ('zimny', 2),
#   ('mocny', 2),
#   ('rumieniec', 1),
#   ('oko', 1)],
#  'kupa': [('uciekać', 1), ('śmiecie', 1), ('stawska', 1)],
#  'dziewięćdziesiąt': [('tysiąc', 23),
#   ('wtrącić', 2),
#   ('pięć', 2),
#   ('lepsza', 1),
#   ('potrzebować', 1)],
#  'ilustracja': [('odtąd', 1), ('zdawać', 1), ('zacząć', 1)],
#  'markier': [('bilard', 1)],
#  'zapewniający': [('otóż', 1)],
#  'przedświąteczny': [('ładny', 1)],
#  'dziarski': [('dopiero', 1)],
#  'uświęcać': [('wyciskać', 1)],
#  'odzienie': [('bielizna', 1),
#   ('nakarmić', 1),
#   ('posyłać', 1),
#   ('wytrzymać', 1),
#   ('rzucać', 1)],
#  'sąd': [('rodzaj', 1),
#   ('naprawdę', 1),
#   ('godzina', 1),
#   ('trapić', 1),
#   ('zajeżdżać', 1)],
#  'gorzko': [('wyrzucać', 1), ('odczuwać', 1)],
#  'ignacy': [('otworzyć', 4),
#   ('zacząć', 3),
#   ('mieć', 3),
#   ('móc', 3),
#   ('chcieć', 3)],
#  'gama': [('zagrać', 1), ('wokaliza', 1)],
#  'surducina': [('wydobyć', 1)],
#  'opierać': [('głowa', 3),
#   ('szczęśliwy', 1),
#   ('zysk', 1),
#   ('marszałkowski', 1),
#   ('móc', 1)],
#  'bośnia': [('ignacy', 1), ('krew', 1), ('niegościnnie', 1)],
#  'przebaczenie': [('biedny', 1),
#   ('szepnąć', 1),
#   ('uklęknąć', 1),
#   ('baronowy', 1)],
#  'rozczulić': [('wypytać', 1),
#   ('stare', 1),
#   ('czarodziejski', 1),
#   ('podnieść', 1)],
#  'poszlę': [('zawołać', 1), ('ojciec', 1), ('spokoić', 1)],
#  'zaniedbywać': [('obowiązek', 2), ('razem', 1)],
#  'uspakajać': [('panna', 1),
#   ('przyjść', 1),
#   ('koniec', 1),
#   ('pocieszać', 1),
#   ('wzruszony', 1)],
#  'trwała': [('para', 2),
#   ('widzieć', 1),
#   ('książę', 1),
#   ('zacząć', 1),
#   ('zbyt', 1)],
#  'szyld': [('swój', 1),
#   ('mincel', 1),
#   ('odejść', 1),
#   ('serce', 1),
#   ('żółtawy', 1)],
#  'nabytek': [('zamiast', 1)],
#  'kandydat': [('kary', 1), ('małżeństwo', 1), ('lokator', 1)],
#  'utrwalić': [('instynkt', 1), ('utrwalić', 1), ('powtórzyć', 1)],
#  'ażem': [('august', 1), ('schwycić', 1), ('wyjechać', 1), ('czego', 1)],
#  'świetnie': [('odeprzeć', 1), ('raczy', 1)],
#  'padać': [('wokulski', 2),
#   ('pokój', 1),
#   ('sklep', 1),
#   ('stolik', 1),
#   ('całować', 1)],
#  'łatwość': [('przerzucać', 1)],
#  'myć': [('zamiatać', 1), ('schody', 1)],
#  'brzęczeć': [('muzyka', 1), ('ucho', 1)],
#  'spostrzegać': [('wyraz', 2),
#   ('siedzieć', 1),
#   ('ignacy', 1),
#   ('para', 1),
#   ('swój', 1)],
#  'politurować': [('przyjrzeć', 1)],
#  'miasto': [('mówić', 3),
#   ('wokulski', 3),
#   ('myśleć', 2),
#   ('choćby', 1),
#   ('urzędnik', 1)],
#  'umeblowanie': [('literalnie', 1)],
#  'powątpiewać': [('dokładność', 1), ('rozum', 1)],
#  'poświst': [('głowa', 1)],
#  'altanka': [('rozlec', 1)],
#  'zły': [('posądzić', 2),
#   ('czas', 2),
#   ('widzieć', 2),
#   ('dzienić', 1),
#   ('mówić', 1)],
#  'jęk': [('grzmot', 1), ('kolumna', 1), ('objąć', 1)],
#  'ducrotem': [('układać', 1)],
#  'zorganizować': [('stworzyć', 1), ('zrobić', 1), ('pracownia', 1)],
#  'gorset': [('tuileries', 1)],
#  'militaryzm': [('wszechświatowy', 1)],
#  'adiutant': [('trębacz', 1)],
#  'nurtować': [('ziemia', 1),
#   ('potrzeba', 1),
#   ('chcieć', 1),
#   ('miejsce', 1),
#   ('głuch', 1)],
#  'usychać': [('ażeby', 1)],
#  'przypinać': [('róża', 1)],
#  'rachunek': [('ostatni', 2),
#   ('rozum', 1),
#   ('wypaść', 1),
#   ('wziąć', 1),
#   ('pierwszy', 1)],
#  'przypatrzyć': [('wokulski', 3),
#   ('uwaga', 2),
#   ('wielmożny', 1),
#   ('niezwykle', 1),
#   ('uważnie', 1)],
#  'dwieście': [('rubel', 3),
#   ('kolej', 1),
#   ('pięćdziesiąt', 1),
#   ('furman', 1),
#   ('złoty', 1)],
#  'błagalny': [('zaraz', 1)],
#  'europejski': [('warszawski', 1),
#   ('znakomitość', 1),
#   ('wojna', 1),
#   ('nieszczęśliwy', 1),
#   ('recenzent', 1)],
#  'irytować': [('osobny', 1)],
#  'stacha': [('móc', 1),
#   ('skurczyć', 1),
#   ('mniej', 1),
#   ('uwaga', 1),
#   ('koń', 1)],
#  'paplać': [('spoglądać', 1)],
#  'ciężko': [('podnieść', 2),
#   ('nieraz', 2),
#   ('schylać', 1),
#   ('towarzystwo', 1),
#   ('odwrócić', 1)],
#  'beleć': [('rzec', 1),
#   ('powaga', 1),
#   ('nieumiejętność', 1),
#   ('prosić', 1),
#   ('mówić', 1)],
#  'jubiler': [('odnieść', 1)],
#  'szarfa': [('wziąć', 1)],
#  'przyprzążka': [('załatwiać', 1)],
#  'nastać': [('kawaler', 1), ('długi', 1)],
#  'ocienić': [('przejść', 1)],
#  'biały': [('cylinder', 2),
#   ('anioł', 2),
#   ('linia', 1),
#   ('fartuch', 1),
#   ('niebieski', 1)],
#  'wycofywać': [('parszywy', 1), ('dobra', 1), ('kapitał', 1), ('udział', 1)],
#  'uplacować': [('chłopak', 1), ('pierwszy', 1), ('starowina', 1)],
#  'oset': [('wznosić', 1)],
#  'rozchorować': [('ściskać', 1), ('krzeszowski', 1)],
#  'serdeczny': [('iskra', 1), ('chcieć', 1), ('wokulski', 1), ('ostatni', 1)],
#  'arcyksiążę': [('rudolfa', 1)],
#  'potrącić': [('baron', 1),
#   ('cóż', 1),
#   ('konsekwencja', 1),
#   ('milczeć', 1),
#   ('powiedzieć', 1)],
#  'grunwaldzki': [('obraz', 1)],
#  'najniewypłacalniejszych': [('sprawa', 1)],
#  'wieszać': [('miewać', 1), ('ręka', 1), ('wczoraj', 1)],
#  'gubernator': [('rzymski', 1)],
#  'stronnik': [('groszowy', 1)],
#  'sztuca': [('musset', 1)],
#  'dopóki': [('zobaczyć', 3),
#   ('wreszcie', 2),
#   ('drugi', 1),
#   ('wypełnić', 1),
#   ('raczek', 1)],
#  'wystawiać': [('ażeby', 1), ('próba', 1)],
#  'przysłać': [('ukłonić', 1),
#   ('dodać', 1),
#   ('przepraszać', 1),
#   ('pieniądz', 1),
#   ('rok', 1)],
#  'przeprowadzać': [('wolno', 1)],
#  'spłacać': [('dług', 2), ('dawny', 2), ('prosić', 1)],
#  'ogon': [('dokładnie', 1), ('ignacy', 1), ('opierać', 1), ('nareszcie', 1)],
#  'girlanda': [('pieścić', 1)],
#  'spotkanie': [('wąż', 1), ('miejsce', 1), ('nadawać', 1), ('znajomy', 1)],
#  'roślina': [('zdobić', 1), ('właściwy', 1), ('zwierzę', 1)],
#  'bodajby': [('paść', 1),
#   ('swój', 1),
#   ('stracić', 1),
#   ('wokulski', 1),
#   ('stać', 1)],
#  'dalejże': [('lokator', 1), ('tymczasem', 1)],
#  'klep': [('wypukły', 1)],
#  'szwalnia': [('ciekawy', 1)],
#  'nieco': [('zmieszać', 2),
#   ('zesztywniały', 1),
#   ('racja', 1),
#   ('pokój', 1),
#   ('oprzytomniać', 1)],
#  'nachmurzyć': [('wokulski', 1), ('wziąć', 1)],
#  'przedsiębierca': [('artykuł', 1)],
#  'rozstać': [('wymieniać', 1), ('zatopić', 1), ('panna', 1), ('warszawa', 1)],
#  'uściskać': [('wziąć', 1),
#   ('kochany', 1),
#   ('rzec', 1),
#   ('zatrzymać', 1),
#   ('oba', 1)],
#  'rozwidlać': [('droga', 1)],
#  'nieprzyzwoicie': [('pchać', 1)],
#  'mania': [('wynalazek', 1), ('założyć', 1)],
#  'rączka': [('buzia', 1),
#   ('nóżki', 1),
#   ('swój', 1),
#   ('asystować', 1),
#   ('ściskać', 1)],
#  'niebezpieczeństwo': [('widzieć', 1),
#   ('tutejszy', 1),
#   ('trupi', 1),
#   ('postanowić', 1),
#   ('zdobywać', 1)],
#  'trącić': [('rzecki', 1), ('nagle', 1), ('brzeg', 1), ('rękaw', 1)],
#  'wyprocesować': [('mąż', 1)],
#  ...}

# %%
def random_chapter(top_successor, word, length):
    chapter = [word]
    current = word
    for _ in range(length):
        successors = top_successor.get(current, [])
        words, weights = zip(*successors)
        next_word = random.choices(words, weights=weights, k=1)[0]
        current = next_word

        chapter.append(next_word)

    return " ".join(chapter)

random_chapter(top_successor, "sklep", 50)
random_chapter(top_successor, "izabela", 50)
random_chapter(top_successor, "geist", 50)
# Out:
# 'geist przeciągnąć mieć zamiar wyjście chętnie pójść sklep wokulski spojrzeć panna izabela pójść swój gabinet czytać nareszcie wejść drugie wokulski móc zrobić wielki świat mieć zamiar kupić soba sprawa trzymać ręka noga oprzeć broda ksiądz trzymać ręka noga brudny budynek mieć zamiar kupić ażeby móc miecić szczęście dodawać cichy westchnienie drzwi'
